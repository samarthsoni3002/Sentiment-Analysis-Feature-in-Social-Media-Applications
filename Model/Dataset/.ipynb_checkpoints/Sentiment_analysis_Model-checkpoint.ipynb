# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import one_hot
import nltk 
import re
from nltk import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout,SpatialDropout1D

# %%
df = pd.read_csv("https://raw.githubusercontent.com/dD2405/Twitter_Sentiment_Analysis/master/train.csv")

# %%
df.head()
# Out:
#    id  label                                              tweet
# 0   1      0   @user when a father is dysfunctional and is s...
# 1   2      0  @user @user thanks for #lyft credit i can't us...
# 2   3      0                                bihday your majesty
# 3   4      0  #model   i love u take with u all the time in ...
# 4   5      0             factsguide: society now    #motivation

# %%
X = df["tweet"]
y = df["label"]

# %%
X
# Out:
# 0         @user when a father is dysfunctional and is s...
# 1        @user @user thanks for #lyft credit i can't us...
# 2                                      bihday your majesty
# 3        #model   i love u take with u all the time in ...
# 4                   factsguide: society now    #motivation
#                                ...
# 31957    ate @user isz that youuu?ðððððð...
# 31958      to see nina turner on the airwaves trying to...
# 31959    listening to sad songs on a monday morning otw...
# 31960    @user #sikh #temple vandalised in in #calgary,...
# 31961                     thank you @user for you follow
# Name: tweet, Length: 31962, dtype: object

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 31957    0
# 31958    0
# 31959    0
# 31960    1
# 31961    0
# Name: label, Length: 31962, dtype: int64

# %%
ps = PorterStemmer()
cleaned_text_ps = []
def text_preprocessing_ps(l):
    text = re.sub("[^a-zA-Z]", ' ',str(l))
    text = text.lower()
    text = text.split()
    text = [ps.stem(word) for word in text if not word in stopwords.words("english")]
    text = ' '.join(text)
    return text

# %%
cleaned_text_ps = []
for i in range(len(X)):
    cleaned_text_ps.append(text_preprocessing_ps(X[i]))

# %%
cleaned_text_ps
# Out:
# ['user father dysfunct selfish drag kid dysfunct run',
#  'user user thank lyft credit use caus offer wheelchair van pdx disapoint getthank',
#  'bihday majesti',
#  'model love u take u time ur',
#  'factsguid societi motiv',
#  'huge fan fare big talk leav chao pay disput get allshowandnogo',
#  'user camp tomorrow user user user user user user user danni',
#  'next school year year exam think school exam hate imagin actorslif revolutionschool girl',
#  'love land allin cav champion cleveland clevelandcavali',
#  'user user welcom gr',
#  'ireland consum price index mom climb previou may blog silver gold forex',
#  'selfish orlando standwithorlando pulseshoot orlandoshoot biggerproblem selfish heabreak valu love',
#  'get see daddi today day gettingf',
#  'user cnn call michigan middl school build wall chant tcot',
#  'comment australia opkillingbay seashepherd helpcovedolphin thecov helpcovedolphin',
#  'ouch junior angri got junior yugyoem omg',
#  'thank paner thank posit',
#  'retweet agre',
#  'friday smile around via ig user user cooki make peopl',
#  'know essenti oil made chemic',
#  'euro peopl blame ha conced goal fat rooney gave away free kick know bale hit',
#  'sad littl dude badday coneofsham cat piss funni laugh',
#  'product day happi man wine tool weekend time open amp drink',
#  'user user lumpi say prove lumpi',
#  'user tgif ff gamedev indiedev indiegamedev squad user user user user user',
#  'beauti sign vendor upsideofflorida shopalyssa love',
#  'user smile media pressconfer antalya turkey sunday throwback love',
#  'great panel mediat public servic ica',
#  'happi father day user',
#  'peopl went nightclub good night man action mean peopl lost famili forev rip orlando',
#  'never chanc vote presidenti candid excit cycl look differ',
#  'alohafriday time exist positivevib hawaiian user user user user',
#  'user rip fellow nohern ireland fan sadley pass away tonight gawa forev sing cheer fire',
#  'hard monday due cloudi weather disabl oxygen product today goodnight badmonday',
#  'unbeliev st centuri need someth like neverump xenophobia',
#  'taylorswift bull domin bull direct whatev want w',
#  'morn travelingram dalat ripinkylif',
#  'user one word tell photoshop enoughisenough dontphotoshopeveryth wheresallthenaturalphoto',
#  'oh cedarpoint wait hour valravn line stop work close',
#  'thank sunshin thank posit',
#  'final finish book work awhil bookworm ontothenextnovel',
#  'yup knick fan hard easier nba fan playoff roll around',
#  'life social network embrac day',
#  'mom share bihday user bihday snake see weekend',
#  'love echeveria bloom flower grow garden iphonesia bliss bloom basilicabotanica',
#  'amaz posit affirm',
#  'model love u take u time ur',
#  'whenev im someth goe wrong',
#  'feel blue illustr',
#  'best pa life know',
#  'abc get readi remov victum frm pulseclub prayfororlando',
#  'bihday got nose job user bihday petunia love',
#  'concelebr albanpilgrimag first time user',
#  'user let scum baggeri begin',
#  'thank super love zpamdelacruz wed dolor capa tarlac',
#  'scourg play baroqu piec piano beyond belief',
#  'user let fight love peac',
#  'happi father day mr rayo video father day rayo world hotvideo video',
#  'user ascot time babe ascot fashion monochrom style instahappyday',
#  'weekend selfi yolo xoxo like like',
#  'happi work confer right mindset lead cultur develop organ work mindset',
#  'christina grimmi last perform shot via user christinarip voic christinagrimmi',
#  'readi danc roar preschool student proud',
#  'realli hu feel',
#  'user wife ador miss poland show surgeri name bridget amp everyth',
#  'user jealou right chatiado',
#  'celebr everi man play fatherli role father day',
#  'sure happi hour',
#  'white establish blk folx run around love promot great',
#  'good morn journey begin travel yeah thejourneybegin hello',
#  'user luv hottweet like venusexchang',
#  'new brochur arriv excit awork solut',
#  'much stuff happen florida first orlando shoot disneygatorattack two year old kid',
#  'user ferrari sake championship gp clearli turn point rb ferrari merc',
#  'ace first test proud',
#  'seek probe udtapunjab leak point finger amarind aap',
#  'user wrap senseaboutmath user th user user user',
#  'user hey white peopl call peopl white user race ident med',
#  'user user might shown today regurgit talk point name call',
#  'sometim rais brow rais bar golfstrengthandcondit strong felixfoisgolf',
#  'greathonour careerconvo user user',
#  'user design innov learn space user includ wateringhol cave mountaintop campfir user h',
#  'altright use amp insecur lure men whitesupremaci',
#  'carri gun help take gun control stop black market terror get wors',
#  'use power mind heal bodi altwaystoh healthi peac',
#  'woohoo week go',
#  'far away place famili member hu',
#  'readi rehears tonight new music new video look announc midweek newmus watchthisspac guitar',
#  'monday night pm channel final get see fuss',
#  'watch new episod user user',
#  'user offlin nice long night snapchat user redhead vermillionr',
#  'thing incred peopl',
#  'ye receiv accept letter master back user octob goodtim histori',
#  'daughter ride bike around driveway son play guitar us enjoy campfir summeim memori',
#  'omg love station way jam work get work done cours memori user',
#  'user alway hope one day get hug think gonna happen anytim soon',
#  'model love u take u time ur',
#  'coupl sex fat nake japanes girl',
#  'hump hump day humper edwardsvil pennsylvania',
#  'personalis gbp get shop cool home fun',
#  'truli sick ppl',
#  'trump call obama resign orlando shoot boy point year talk chang',
#  'user user user user long nashvilletour nashvilleforev',
#  'eur usd clear barrier jump fresh week high blog silver gold forex',
#  'go la tomorrow',
#  'thank good friend thank posit',
#  'still wrap head around fact christinagrimmi gone fact man destroy prayfororlando',
#  'receiv di user wait sta bake eyelid',
#  'play vigilfororlando harp clonakilti rip via user',
#  'user ye ye ye ihavenofriend someonecomewithm',
#  'sunday weekend relax icon woman sundaymorn sunday marilynmonro',
#  'user interest linguist address race amp racism power raciolinguist bring',
#  'one belov long lost cd recov thank appl music',
#  'marvel song musica weed ripchristina adel danc vine user',
#  'user user mock obama black user user user user brexit',
#  'spell brexit referendum commerzbank blog silver gold forex',
#  'amaz health benefit cucumb healthi altwaystoh',
#  'model love u take u time ur',
#  'work ofw pinoy followm iger instagood smile love',
#  'toradora anim animeedit made breakup alon lone',
#  'lap pool k ride done pick gym membership form',
#  'cotd polar bear climb race angri polar bear climb race polar bear live cold place look',
#  'user user get angri muslim assassin much',
#  'happi snappi wait footbal footbal snapchat',
#  'friday miss fring qcbag summer',
#  'nochebuena lasvega usa la vega strip',
#  'fleurett instaboy instaman sefi septum friend smile blackandwhit',
#  'sad branch raini day write tear fli bird haiku line micropoetri',
#  'yeah new button mail pretti jewelrymak button',
#  'user driver hit femal moos river rd weston moos kill driver ok crew remov anim',
#  'afterpa made japan madeinjapan eo cute fun cawaii love strawberri tomato',
#  'peopl protest trump republican trump fuher amp',
#  'need find way spend time alway mind boy guy',
#  'updat social analyt photooftheday iger like',
#  'anyon know date doj fbi becam corrupt emailg hillari shame disgrac ridicul',
#  'stupid make even neglig put sachintendulkar instal u go take',
#  'bihday thbihday bestfriend love',
#  'user impoant thing enjoy life matter life sho pooh u',
#  'happi bihday chri evan great actor human chrisevan bihday',
#  'hea thought prayer go peopl murder gay nightclub florida',
#  'user demo guitar new album newalbum indi guitar echobelli',
#  'retweet lion pro user tgif webmaret seo commun manag weekend',
#  'nzd usd target week sma blog silver gold forex',
#  'user pretti bad bihday week far worst ever bihdayweeksuck bithday',
#  'bless work sa best lead ladi',
#  'happiest place eah disneysmagickingdom disney magickingdom disneyland orlando',
#  'kinda among human',
#  'found user user exclaim user gr blain hair nite',
#  'user lt listen beauti best friend user sing amaz voic lt lt lt lt',
#  'n healthi freedom effo present mere mean effo store past theodor roosevelt',
#  'know yall aint go know love commit trust faith',
#  'ye call michelleobama gorilla racist long thought black peopl bet',
#  'newarkfestiv us year wait show sta rd year run',
#  'internet broken watch netflix mochithepug puglif',
#  'user user user busi usual',
#  'hbd dick suckin tequila lovin slut wouldnt want u way justalil butstillontim',
#  'smaller hand show barri probabl lie knick game suck golf',
#  'good morn friday everyon weekend goodmorn friday girl love florida',
#  'challeng aap claim punjabi drugaddict dare prove',
#  'tracerequest send deepest condol orlando gay famili zimbabw gay commun hea touch',
#  'new selfi guy mato chapon',
#  'saturday afternoon chi meet friend user user user',
#  'model love u take u time ur',
#  'so nut amp bolt bloke',
#  'aww yeah good bing bong bing bong',
#  'dawn month see user live excit vfest summer',
#  'user happi th bihday shane robe watson bihday shane watson australia cricker',
#  'user user point one finger user million point right back jewishsupremacist',
#  'sad hear announc say may move player one two lead whoknow',
#  'radio go coldplay tonight oh ye',
#  'u think like god come god keep',
#  'user terrorist constitut right anoth excus republican appeas nra gun control measur',
#  'user user gloucesterrugbi',
#  'user sad user happen',
#  'everyon everyth sad togeth alon fine dandi lone exuber depress halfful halfempti',
#  'mikeashley sposdirectsham perhaps good exampl need protect workersright within europ euref remain',
#  'angri bird stella bad princess bird stella bad princess birdsstellabadprincess time post wed',
#  'check user incred made great memori great peopl',
#  'saw shi last night said rip care realli',
#  'user hilari user alreadi block user ask one paicularli difficult question user',
#  'devast news hea goe victim famili orlando heabreak',
#  'happi state arriv manner travel margaret lee runbeck happi quot inspir',
#  'safe way heal acn altwaystoh healthi heal',
#  'creat right beat makingbeat thursday work istandard akaipro',
#  'wed number wed weddingpay love forev weddingdress',
#  'look forward attend cipd ireland confer amp workshop cpd onemoreday user user',
#  'final reach follow twitch follow hypu stream tomorrow',
#  'word r free u use em cost verbal abus hu love adult teen user',
#  'countri went last year see peopl bring bomb stadium amp come everyth footbal',
#  'thank cat thank posit',
#  'time eat bae swalscha dejeun lunch happi love amoureux',
#  'ilovethesecret lawofattract quiz love happi motiv success joy life',
#  'might libtard libtard sjw liber polit',
#  'go pole bgp rozthediva blackgirlspol bodyandpol live love',
#  'argentina attack bull game realli think head empti around citi side',
#  'self serv hypocrit alway keep eye bounc ball nimrod presid',
#  'nohcarolina bull domin bull direct whatev want whe',
#  'build polar bear climb race angri polar bear climb race polar bear live cold place loo',
#  'user user want reelect money ksleg',
#  'hea orlando right truli cannot imagin could easili happen anywher',
#  'alreemgroup ali alshahawi ad cute summer photographerdubai sun hair mydubai',
#  'seem like place action montreal',
#  'user old wash',
#  'spirit posit affirm',
#  'thank enteain thank posit',
#  'user user user show truli bad brisban',
#  'user wait wimbledon',
#  'happi man success model entrepreneur speaker ff fresh confid fashion',
#  'gala moment day kid bipolar frikiegirl lucki chinatown mall binondo',
#  'realli take piss angri goe show valu complet utter moron',
#  'user take trash america vote hate vote vote vot',
#  'father day amaz dad give much famili enjoy',
#  'magnettherapi realli work altwaystoh heal healthi',
#  'sebbo said user',
#  'eg smile smile egsmil torio',
#  'user brilliant servic ketter branch today custom',
#  'user screen miss sing song potp shock treatment',
#  'way toraya bu alamindah white music carrieunderwood',
#  'model love u take u time ur',
#  'good day new beer bridpo food amp beer fest back campsit drunk user starstruck amp move user',
#  'g l repost user propey ocean summer life famili sydney',
#  'want teach love like never felt quot quot love pakistan allin girl boy fashion feel',
#  'thank thank posit',
#  'omg day left countdown nolefam user wait come milan',
#  'user stone rose done time user club day',
#  'reason two peopl stay togeth give someth nobodi els hopelli great day',
#  'never know might crush wakow buzz moment ride love crush date hookup app',
#  'friend got engag',
#  'day lef b end classez yay risay risaypl',
#  'thursday may watch say need said',
#  'legendari posit affirm',
#  'unit state america rest world think proven right firearm',
#  'hold open door woman woman nice thing even tri deni',
#  'good weekend show thank bless jeffreycwilliam',
#  'good hea help everyon alway seem one get hu buttru',
#  'happiest babi ive ever known cute smile babygirl beauti niec bless xo',
#  'readi b c oneteamlincoln user user user user',
#  'wait carowind readi see user user time rockthepark timetogetmyjesuson',
#  'alreadi bought find dori ticket',
#  'everi minut lose sixti second happi',
#  'sanjapan animeconvent see guy septemb',
#  'question day excit moto tech announc moto question',
#  'make today count mondaymotiv livelifetothefullest healthi everydaycount',
#  'happi morn degre anna classmat friend',
#  'user would u abl suppo event brentwood homesta lost fund may close',
#  'happi littl peopl happyhappi peopl kitten cat blackkitten',
#  'user user user thank much oppoun cherish forev',
#  'themeowood puppi',
#  'day till',
#  'happi pharrel william pharrellwilliam lyric',
#  'user happi w ork confer right mindset lead cultur develop organ work',
#  'lost anoth member famili yesterday gut rosi',
#  'yayyy trailer morrow fever super user user user',
#  'watch fanci tail vine mad mad teeth bite piss dog bite dogbit dogtreat',
#  'dreamcatch bull domin bull direct whatev want',
#  'readi tomorrow englishteach teacher ecuador',
#  'memori wonder dad alway miss etern love strong greatquot',
#  'user user dalla shoot video see disturb viewer discret play loop ove',
#  'itako alon fine littl',
#  'sunshin amp sticker kind saturday letthembelittl childhoodunplug',
#  'wonder day today calm sunni chubbygirl glass finnishgirl finn',
#  'buka bersama tma famili yuhuuuuu tma w risha meylucki amp other mayfair townhous pic',
#  'love know nationalbestfriendsday true',
#  'user man ran governor ny state biggest african american popul',
#  'stereotyp prejudic offer hope solut creat old repetit hate conflict',
#  'get pussi quicker day',
#  'probabl time user come back home ugh',
#  'model love u take u time ur',
#  'user anyon play voez kinda love game game game girlgam voez',
#  'mani pol pass mani time said noth bluelivesmatt draintheswamp ferguson',
#  'sequoia weekend',
#  'bitch care eyebrow much makin end week',
#  'bham pride paradereadi beyou ofbham user user user',
#  'fathersday guy play dad love',
#  'bihday bogummi love forev hope happi everyday good night user',
#  'wish client babi goat cuddl',
#  'positivevib fresh love guy get concord mill mall',
#  'conjur get readi scare tonight readyornot truestori',
#  'today day make chang elimin neg choos live posit lifestyl instead',
#  'user aaahh nabilah look arigat jkt happi daaay iwearbanana',
#  'last day work tomorrow self employ monday scare redditchbizhour',
#  'user im half boy half man im dumb',
#  'happi littl boy smile corbinrayp',
#  'never appropri zero idea feel right scare missyou whatwasthat',
#  'user magnific monday mondaymorn mondaymotiv monday indraloka',
#  'dont understand design print anim fabric bought user muzlin b sanasafinaz noexchangepolici',
#  'mayb happi hour get end',
#  'littlebear friend joy toddlerfriend puresweet latergram toddlerfun',
#  'never lost love one senseless violenc get fuck opinion nd amend',
#  'world head could lose life leav home orlando',
#  'heard say tri lock shooter kept patron get',
#  'good mood flight user munich user interview pharrel',
#  'first present user netherland user',
#  'u made us proud hv read ur word amp assur b assoment petit emot wish u best',
#  'happi vs joy happi temporari leav u hu joy last forev never leav real tru',
#  'twinklatinboy na slut snapshot hot nasti naughti sexi horni shi porn nude kinki xxx',
#  'user peopl thank thank peopl happi thankfulthursday',
#  'creativ posit affirm',
#  'held back tear cri happi tear amp final leav week tomorrow user user canadianrav',
#  'bihday pressi mummi granni michaelkor luckygirl bihday liverpool',
#  'user stuck athen instead santorini user said windi land shock servic everi level sinc',
#  'user happi folk first freakshak launch freak yum dalston user',
#  'huge crowd trump',
#  'thank saturday thank posit',
#  'good god',
#  'user enjoy delici melon vegan organ fresh fruit organ healthi healthyliv life',
#  'first month week day till begin end user sad time',
#  'firework weeheeee',
#  'blackpool attack bull game realli think head empti around citi side',
#  'fathersday amaz father today',
#  'want much ask',
#  'user readi wait newblood',
#  'sad aunt pass away funer',
#  'horribl ad made us cring',
#  'mind robson kanu decent player avail free transfer',
#  'user come user better pleas put user shoe unnecessari stress h',
#  'stalk watch peon poor disabl kill usa usa use b proud amp univers care',
#  'stephcurri outburst beg question christian get nbafin',
#  'grate affirm',
#  'week go im san antonio bound see user cant wait see littl brother missyou mybrotherskeep',
#  'listen gt gt gt gt gt gt gt',
#  'user die light villag green town antisemit hocoschool columbiamd hocomd',
#  'hahaha last friday amp weird',
#  'hey notic u train lover ask u check free app known train appl',
#  'sexi fuck direction niall nialhoranfact niallerwin hot justindrewbieb justindb believet',
#  'user father sday say love dad right sanya whererefreshingbegin',
#  'guess back back lifeaftersurgeri dog dogslif labrador labradorretriev lifeofsam',
#  'hey superspoilt may want check latest updat glastofest',
#  'user user user user user bihday sid god bless hav success career',
#  'nba final ambival love steph thompson kyri stink green class doosh lebron talk guillermo',
#  'check product team web seri episod edit truli mep webseri',
#  'model love u take u time ur',
#  'user never answer statement nazi hatr amp bigotri found w',
#  'juneteenth independenceday food thought rich ancestr heritag independ hall',
#  'river gorilla simul need adapt environ need tear citi materi',
#  'watch user leadership embrac amp kiss donald ass pathet amp user pay pay racism amp hate ripgop',
#  'love matur age',
#  'aww yeah good bing bong bing bong',
#  'user good feel happen smile instalik instamood instap',
#  'check graffiti dublin ireland music vimeo movi video europ peopl flow fun rafalwojcicki',
#  'oitnbseason day aaahhhhh',
#  'user user iamposs today extraordinaryladyspeak staraward user user ht',
#  'sun happi thursday breakfast sun day sunnyday sun blue',
#  'pack sneak peek work yellowjacket neshl user bhl hockey',
#  'toni sunday tonyaward',
#  'happi father day dad dad father day',
#  'user theverdict idiot countri rock bluegrass beatl love pop romanc',
#  'project week june blog silver gold forex',
#  'user dayshappi user dayseventyseven day happi love lifequot life',
#  'littl brother higher toler alcohol lol',
#  'wish guy bihday blaze say user spit imag',
#  'thank hike trail thank posit',
#  'pay meet tackl movi uncov problem want world know',
#  'user chill relax piano music keep pet quiet juli th firework',
#  'might libtard libtard sjw liber polit',
#  'user noth say merica like user tweet',
#  'alway paratyphoid',
#  'user today lost thevoic sister senselessli sing love death peopl stoptheh ripchristina',
#  'guy concern twitter brand honest follow',
#  'hate like famili realli born big ass toxic bomb mother fucker give fuck cuz got money',
#  'get get get enjoy music today free app free music',
#  'best lawofattract resourc heal altwaystoh healthi idwp',
#  'trump ny co chair make racist remark michel obama p p fyi tcot',
#  'user fan make',
#  'music therapi tool heal altwaystoh healthi',
#  'food make famili fight mxm',
#  'delici sangria salud cheer smile pub pembrok',
#  'fabul weekend beauti soul nofilt',
#  'feel overwhelm look see million reason happi love craig',
#  'back day job shane lowri',
#  'hour right bottl amp drink pm user w chippewa st buffalo',
#  'ana nimra farishta mawia khushal number mark obtain damn high p',
#  'monday empti without bachelorett thebachelorett empti nowin',
#  'suppo famili god chivalri tradit pride one heritag controversi',
#  'user pic say otherwis young girl confin kitchen void mean beyond cheap public topoli',
#  'good night faith ever vaitacacommafiasdv',
#  'love simpli love love success work busi',
#  'lunchtim mom torrington lunch afterschool instadaili yummi withmom user',
#  'user sister even know watch argu nigga wait say wrong shit',
#  'ride ride back done cycl sunset ride bike fit cardio dese',
#  'well gonna go see adtr bae',
#  'user tagsforlik food friend summer swag quot love god girl weekend polaroid followm teen win job',
#  'payintheusa polar bear climb race angri polar bear climb race polar bear live cold place',
#  'healthi fam',
#  'dream palac move alreadi stellar girl dreami goodmorn day',
#  'im wait follow sinc x factor',
#  'user fault use pointscor',
#  'user week sta kinda lame get better yay wednesdaywisdom',
#  'user forev user young man luk hot wen temper b alwi ur fan till lst breath h',
#  'worri bee',
#  'doubl tap follow beauti smooth lifestyl skin instas f f fashion',
#  'lawofattract heal loa healthi well idwp',
#  'oil turn flat eye eia inventori data fuher direct blog silver gold forex',
#  'train new employe fun newblood',
#  'first bihday puppi elois sweetbabin dog growingup cute bihdaygirl user',
#  'user pig burn aliv saskatchewan barn fire video',
#  'user never convinc american right bear prayfororlando guncontrol',
#  'beauti ladi bless know smile lovethem',
#  'today baba siddiqu ifftar pay mumbai user amp user dono ayeng see',
#  'hand ombr blue',
#  'user wait go see warcraft ugh warcraft',
#  'cousin reunit famili fun user well',
#  'user audienc duan henri insight',
#  'train move bing tweet',
#  'lover stop angri visit us gt gt gt lover friend astrolog love',
#  'user block troll promis blacklivesmatt amp let nonsens rant boo',
#  'father day dad one heaven',
#  'sdl user june user',
#  'creepi awesom baboon climb fire escap like human user summev zoo',
#  'use power mind heal bodi altwaystoh healthi',
#  'dude tiger roar tiger annaswelshzoo bihdaycelebr',
#  'user laugh happi laugh william jame xtra',
#  'happi sunday everyon think today go good day positivevib sunshin sunday',
#  'talk way organ dehuman us never held account',
#  'stuck rat race find freedom masterkeyexperi',
#  'studi face pizza stole roommat idea take pic',
#  'dinner sister sisteradventur sister ilovemysist',
#  'els plan watch user tomorrow',
#  'usn rifl day snow ar closest ever got user user user navi',
#  'euro bbc pundit make predict franc euro sta today',
#  'user happi happi minion',
#  'elder scroll mani year wah wah bethesda e e',
#  'user poor tiggi littl bit cheeki jax amp soa throwbackthursday user user user',
#  'cannot wait eurogam year pump eurogam',
#  'work russel beckwith soon staytun friend lyle tapfoag',
#  'nazi studi american race law inspir ushistori eugen',
#  'share ice cream sun love outdoor picnic summer famili daughter father dess icecream',
#  'noth like river island sale shop spree cheer retailtherapi riverisland shoppingqueen alwayscheersyouup',
#  'clean ze hous zo ziy laundri final free fever cold happi clean laundryday',
#  'new list ebay woohoo sell sell buy shop shop',
#  'thank challeng thank posit',
#  'chill night ice cream amp grown chill',
#  'user biher absolut origin hate bigotri altright hatr african american potu theresist',
#  'user sweet instagood idola idol followm selfi',
#  'tragedi america first kill christinagrimmi orlando america safe place today',
#  'brexit angst factor help drive interest rate germani japan bbh blog silver gold',
#  'fab amp interest day eacbpm dash quiet place dial iiba emea region meet busi',
#  'kayak sup snorkel swim whatev pleasur put togeth alohabeachbu hawaii explor',
#  'u hold man year watch chang u hear say loyalti',
#  'back go tacloban see ya later great travel tacloban citi catbalogan',
#  'user feel olymp medal',
#  'angri bird il film download ita p hdtc bird download film il ita',
#  'sunday photo user model urbex topless tit mono retweet sexi heel ace',
#  'fo woh offic viral arrest video rude racist chief crime offic',
#  'user user user user saturday friend',
#  'yayyyi friend got marri today congratul guy shegotmarri',
#  'model love u take u time ur',
#  'lewi remain perfect ranger announc gonna stroke',
#  'chri back soccer miss spring season broken',
#  'train ticket book opera week wale',
#  'beauti day sun fun beachpark beach park',
#  'big screen fit right euro',
#  'love stori happi end anim love stori end like like',
#  'poet bull domin bull direct whatev want sta',
#  'tranquil posit affirm',
#  'user name upcom new track pm kpop',
#  'best essentialoil anxieti healthi peac altwaystoh',
#  'user user user wow peopl children noth better insult peopl twitter',
#  'think mayb bought user instead user gettingold becomingbor notborderland goblizzard',
#  'fact user album hour away drip lose mind fatkidinacandystor',
#  'ryderrideu see c c cum togeth snapshot young shi kinki wet porn hot xxx horni',
#  'snapchat gabi china love girl snapchat flower instasmil instalov',
#  'brilliant posit affirm',
#  'user true nigga dont go look apament go look shoe jewelri',
#  'safe way heal acn altwaystoh healthi heal',
#  'msgapparelstoday user u r special us father day',
#  'camp next weekend lovecamp brownwood',
#  'grate affirm',
#  'forev besti karaok friend friendship love nofilt instacool instagood',
#  'user absolut love place fantast welcom carlo receptionist th time room request grant usual',
#  'head thealter peculiar famili',
#  'us retail sale control group like rose may dansk bank blog silver gold forex',
#  'happi father day love life amp best father world user fathersday love',
#  'coolestlifehack world smallest snake motiv',
#  'shockingli increasingli violent world live uk gun control law feel mp famili amp friend',
#  'funni simpli truestori',
#  'happi bihday brithday day holiday monday menmodel',
#  'sadden one thought groom posit ask opinion issu',
#  'ukrainian athlet grosseto user watch livestream without see',
#  'new season oitnb sta tonight oitnbseason',
#  'user excit side cuain tonight look forward see user broadway',
#  'quay collab user say sold noooo whyyyy loveyoudesi',
#  'final get jordan get paid wear lowtop',
#  'impress posit affirm',
#  'father day father make happen salut',
#  'view th floor nyc newyorkc myview girl wine fridaynight',
#  'discuss republican thing critiqu ignor consequ',
#  'got school tomorrow last integr',
#  'amen truth alway lt lt love bless',
#  'user stamford kid got month rape boredom minut action',
#  'let color life w rainbow danian love colour rainbow depok',
#  'aiel aielmaharashtra rude custom care execut make want switch loyalti anoth provid irrit',
#  'hi teddi corpuz rocksteddi band enjoy idol omg',
#  'user wow great daughter send father right father day cheapshot lowblow shame',
#  'reason happi kid mid tantrum parent tantrum toddler calm mind strong',
#  'truth posit affirm',
#  'yup siri maco wwdc woot next work listen skill',
#  'diy done dresser nicknack newelectricscrewdriv brock london',
#  'black amp feel like stomp retweet tampa miami',
#  'user user that problem one polic offic need bigger gun perhap one tank soldier',
#  'father day friend',
#  'choic fall alway write candid',
#  'user end',
#  'get know team behind app keep tummi june issu user bazaarmag',
#  'actual go fish today somewher nice',
#  'cute look like doll',
#  'user im',
#  'love vacat enjoy greec crete sabinedrift chillinn blondegirl bluedress',
#  'user unreal advisor refus take payment say wait pcn custom servic ur site wasnt work',
#  'user gamereadi forza horizon pc time live',
#  'user life better tahiti summer life school tahiti like',
#  'know male thought vagina like video game xd stupidthought quot lmao',
#  'pa pack taken brainwash cheetah downasquadmemb treeout',
#  'japan domest corpor good price index yoy line expect may blog silver',
#  'rememb day peopl bbuk went becom realiti tv star seem realiti tv star becom big brother contest',
#  'user allahsoil familiar becom difficult stereotyp',
#  'user good morn want live life tie goal peopl thing',
#  'user friday lt fridayfeel relax user bristol',
#  'day porn movi pussi pay pic',
#  'look easi till turn rap hiphop rock funni comedi pop kanyewest',
#  'banner merri christma new year freepik ad decor newyear',
#  'user user yay thank let know pa happi man',
#  'exam room test tire annoy',
#  'best homeopath remedi anxieti altwaystoh heal peac',
#  'rest peac christina',
#  'bama fool around might rais child ppl dont think far advanc see fun whatev',
#  'anti racist codeword antiwhit asia asian africa african white countri everyon',
#  'user periscop first god babi graduat high school collegebound',
#  'nearli folk nervou curiou finalis stuff pointer grainn bringiton',
#  'fellowship lifegroup',
#  'caught eat chocol slice bread besid ref realiz still eat dinner',
#  'user prais cleveland polic rnc polic consent decre white tamirric rip',
#  'best lawofattract resourc heal altwaystoh healthi idwp',
#  'everyth need surfday fathersday dad novyspo novytowel surfgear',
#  'user agre',
#  'user next show monday fiddler elbow camden look like go huge night ht',
#  'user swim sign everywher parent watch year old',
#  'mitchellrattl mitchel goodson',
#  'user get readi saturday jeep run nbjc day showyourjeepday jeepmafia jeeplif jeep htt',
#  'user attempt czech furi croatia score second',
#  'latest dairi k thank user user user',
#  'user yep grate everyday gratitud laurasworld',
#  'ebook awhil nice hard copi',
#  'nba final game could basketbal fan ask nbafin',
#  'user prevent bigot',
#  'dear uot despit attempt savechar regret announc lost tragic rip angel friend miss u',
#  'space place color blue fabricsourc finish pillow cushion use us',
#  'perfect moment day',
#  'wait user hour come autograph final walk away come cours disappoint',
#  'fathersday gift dad secur financi futur save insur invest',
#  'girl world sexi matur housewif',
#  'time get happi saturday saturday weekend',
#  'awesom dad almighti father lord darl dad rip sweethea husband babi daddi st son fathersday',
#  'owen footbal tornament footbal',
#  'come ee piss poor recept today month struggl get signal buxton put mast switch grumpi',
#  'excit na',
#  'user let troopingthecolour begin bihdayyourmajesti thequeenat ht',
#  'work fusiona wolv last stage develop chase user user',
#  'user like blacklivesmatt slogan talk',
#  'r p littl bear bear hamster rip imissy',
#  'give hug love cat moment',
#  'lip like fire blood like gasolin love boyfriend smile',
#  'go let peopl icr',
#  'life race allow present user fun',
#  'dental testimoni lichfield client',
#  'thank soo much pretti user feel soo bless amp lucki plz keep shower ur lyk surpris like unexpect',
#  'user user user nice c susanna smile day need fals promis fli dragon got ben',
#  'user back yet',
#  'got call yesterday mom diagnos stage ovarian cancer terrifi terrifi know',
#  'user feminismiscanc feminismisterror feminismmuktbharat malevot ignor user',
#  'user user user side histori alli issu embarrass',
#  'fox new come say bluntli one thing read',
#  'good morn internationaldayofyoga yogalov yoga relax healthi posit',
#  'user monkey also declar vermin protest bajrang dal user user',
#  'user new plant user readi garden garden know',
#  'user coldplay last night fave coldplay conc hampden fave coupl cute',
#  'use power mind heal bodi altwaystoh healthi peac',
#  'flagday mine gorgeou texa sky householdnam takingov',
#  'aww yeah good bing bong bing bong',
#  'user ye let suppo openli prowar anti islam homophob rapist advoc hypocrit',
#  'cat furri persiancat pixion wallpap imag',
#  'good moooooorn tgif kiss kiss friday fridayfun',
#  'user enjoy everyth alreadi given rather alway need bless thank',
#  'euro match schedul design franc vs romania feedback appreci',
#  'father day take dad user love',
#  'berlin thank much user incred theriveourberlin theboss',
#  'listen incubu never hu nowplay sick littl world nissan live set de user',
#  'user anderson cooper amp lemon like gay thrown build sharia ndamend',
#  'bei field dog walk dog',
#  'would steal awork user boohiss',
#  'compet list today whenrealtorscompeteyouwin callm gotheextramil',
#  'user great park total disorganis one poaventura whatajok',
#  'got news berni win dc even vote held last month dcvote',
#  'eur usd print new monthli top draghi eye blog silver gold forex',
#  'two presidenti candid everybodi devolv elect america smh usa',
#  'poor pup anim puppi vine magic subscrib youtub vine user',
#  'rare pic superstar user user bihday sivakoratala',
#  'user user move outsid downtown gr mi neither offer better mbp',
#  'user wish dad happi father day dad fathersday intellicr',
#  'met girl yr ago onlin b ng gay friend look like b user',
#  'face say pwcproud',
#  'b u love instagood user tbt cute beauti followm',
#  'enjoy weekend famili home happi weekend dear friend weekend famili home',
#  'anoth senseless tragedi tragic puls orlandostaystrong thoughtsandpray',
#  'user love yrkkh frm bottom hea frm day stare amp v get return uglyspat user user',
#  'captain felix rutland water littl boat behind go grand adventur',
#  'bing watch seri thekil complet avoid footbal',
#  'quot jeremi corbyn fuck go',
#  'happi travel time instamood moment love mylif russian girl model like',
#  'porn vid wwwsmallgirlsexcom',
#  'user tuesday jacki quot taketim make soul enjoylif smile believ dream havefun',
#  'home sweet home call edinburgh sinc move year ago scotland homesweethom famili',
#  'play england vs russia marseil expect high risk game plenti time drink',
#  'aww yeah good bing bong bing bong',
#  'thank sweater weather thank posit',
#  'haunt atmospher studiotim',
#  'user user becom fan give right critic person life idol',
#  'latest obsidian radio daili thank user user user latesnew',
#  'mind blown learn much googl form workshop user cfisdrrr',
#  'user sexi prettypussi sexybbw realmvp',
#  'user back user v traumat month damag bad thought proof plan work onward amp upward excit',
#  'might libtard libtard sjw liber polit',
#  'overwhelm evid compani trump keep echo sentiment amp ideal dumptrump',
#  'user femal beef commun dick ass nigga',
#  'peopl like alreadi forgot nah new name made hashtag weekli basi',
#  'answer',
#  'cherri color symbol warm posit energi necklac price a stone gift amaz beauti',
#  'wait season begin lfc ynwa englishpremierleagu',
#  'user happi father day dad except rogergoodel fathersday goodellsuck',
#  'orb independ brexit poll show leav vote ahead gbp usd slump blog silver gold forex',
#  'user user user mm mm washout flood good take set anoth day golf',
#  'user ya ever sinc zayn left never',
#  'happi father day lovey fathersday sunday father daddi day',
#  'big shock monday need find new home yeah found dream cottag tuesday',
#  'save thousand free search x login x broker actor seeklearn stafresh',
#  'actual order kyli lip kit',
#  'hope famili made arrang make sure bastard user get access',
#  'socialmedia us firm build nuclear reactor india',
#  'smaphon bull domin bull direct whatev want',
#  'lifeisbeauti loveit workhard trainhard matter go bless fitlif',
#  'oscar tabarez talk lui suarez angri reaction spo lui oscar',
#  'play njoyhit hitmusicst us uk eur user join us nice nyc user',
#  'user week go personaltrain full time new slot avail june pl spread',
#  'mother take care ten children sometim ten children cant take care mother',
#  'thank good night sleep thank posit',
#  'play bride nocturn melancholi melancholymus',
#  'tvk fathersday father day tatay daddi enjoy wath tha voic kid',
#  'thank friend thank posit',
#  'thank mason jar thank posit',
#  'nigger lifelesson white kid grew blogpost whitepeopl respect',
#  'user user user congrat user',
#  'via jt user love sinkthepink music instagay celebspot',
#  'user readi user ccmf mychurch frontrow upshow',
#  'utterli peopl incur stupid africa albino kill malawi spark educ campaign',
#  'gold high back around blog silver gold forex',
#  'shock event orlando usa review gun law innoc die first horrif unforgiv',
#  'knowledg posit affirm',
#  'le sister instatravel instamo igdaili instagramhub instagood instalik',
#  'feel lone',
#  'girliguessimwithh tag saddest represent peopl feel forc vote',
#  'h factor mobil app make user want factor click download aric whitepap',
#  'user meanwhil googl violat free speech',
#  'happi work confer right mindset lead cultur develop organ work mindset',
#  'user rochest attack bull chase leav lot despit fact strong sourc f',
#  'user competit',
#  'tattoosleev gorilla simul need adapt environ need tear citi',
#  'ima go cri hour brb',
#  'tell sorrow river river taught flow without complain sepatu dahlan philosophi proverb',
#  'thank memori thank posit',
#  'user sure nasti piec work lmao',
#  'today perfect day happi lifecoach reinventimposs',
#  'sex sex nake women',
#  'thank cocktail thank posit',
#  'dont wait outsid thepeel work homophob taxi driver guy kiss gay melbourn cab',
#  'user guess one want let resid spring street know abl leav hour today',
#  'great morn deborah user smile kind day',
#  'window split screen browser customcasetab noedit',
#  'user peopl use tragedi like fuel hate agenda toward entir group peopl opposit help',
#  'taeyeon unni fire btw realli hope album cover yellow lol',
#  'john mica hell peopl like elect user user totalpolitician outoftouch disgrac',
#  'noth make dad happier tasti meal fathersday',
#  'truth suicid rate young blackboy',
#  'happi sunday homesweethom amaz love istanbul girl beauti instalik',
#  'oh block least love island look forward sunday',
#  'play suzann ciani clock morn music song',
#  'swing swing mybabygirl babi littlegirl park love cute',
#  'help bubbl attack winter bathtim cozi',
#  'move posit affirm',
#  'thing matter mani law regul gun peopl still find way get hand',
#  'user sunflow natur garden photograpi qualiti print amp card',
#  'user didnt stay long emerg home daughter well soo rush home miss ur set',
#  'user great insight trust profess emea growth hack confer growthwithhubspot',
#  'carolyn cooper ugli poor ignor black',
#  'franklin dog sunshin dogsoftwitt',
#  'perfect day buy real furnitur hike user dinner user dess sleepnumb bonustolongrest dnd',
#  'happi face love smile user satisfi hair workit smile face',
#  'love sunday weekend selfi longhair girl selfporait love',
#  'natur perfect bull hill climb reach target complet task surviv str',
#  'model love u take u time ur',
#  'orlando gay men angri amp donat blood massacr',
#  'user golinglob golinuntern fresh air trail run soul keep golinuntern life balanc',
#  'user user monro amp nick best friend amp rosale amp addi kelli amp babymonrosal grimm famili nadalind',
#  'user lie hillari would call secur inquiri liber like mind one eat shit eat shit',
#  'know find incred disrespect take person call meet frustrat',
#  'date night friday pub ilovehim instagay beer billi burnet',
#  'wish user would make phone damn screen shatter cost arm leg still gotta pay fix em',
#  'hea wrench would state mother know son die',
#  'user time fli less week go brilliant user lead summer confer',
#  'fruit time fruit dess instamo photooftheday yvr sweet vancitybuzz',
#  'sad one gt gt gt',
#  'sirf ashiq log follow karen iqbal galib wasi faraz mohsin ki full poetri add follow user',
#  'user minut go armaanamaalontkss user user user',
#  'thank god royal without kansa citi right cleveland disgrac',
#  'get see favorit person tmrrw',
#  'latina buffalo simul buffalo take vicin home way',
#  'world live orlando',
#  'user vacat begun triathlet triathlon coach vacat fearless rul htt',
#  'user bit heabreak reflect',
#  'user peac way sta morn daili chao begin gratitud',
#  'hardcor girl video birday sex xxx',
#  'takalot book order arriv time long weekend away bush bengreenfield',
#  'saysometh bull domin bull direct whatev want',
#  'steph san kana badli need pleas',
#  'user anoth hand amp feet complet berachah best amp tire',
#  'user way ctf book talk inmat paicip user book club program slugg',
#  'readi awesom beat cool dj danc edm hous goodmus mad',
#  'jpi neg extern environ remain suppoiv mufg blog silver gold forex',
#  'mkf collect jasmin moira crossbodi bag wednesday',
#  'current eat steakandshak minut gotten shake order',
#  'gray sad color make feel grayneedstogo',
#  'difficult road often lead beauti destin anon leadership inspir quot inspir',
#  'usd long posit ad eur sho increas anz blog silver gold forex',
#  'r rockallday user user day nois',
#  'user definit mexican fakenewsal',
#  'user new album releas user break loveherbreakup hotgoss',
#  'stand racism hate americad curs congress hater deplor hate',
#  'sunshin sunshin make sky gray',
#  'someth want say someth make happi game gamer xboxon playstat user e',
#  'footbal actual thing mo watchabl bringbackgladi',
#  'happi hump day humpday life lifestyl wednesday midweek snapchat walru funni',
#  'let say love',
#  'worri happi via user archiveday weekendblogshar happi quot tshi',
#  'great thing never came comfo zone goodtogreat inspirem love',
#  'happi puppi london puppi thursdaymotiv',
#  'know go room one troubl soul draw blackandwhit',
#  'recommend dark amp romanc horror moviegenr ambianc',
#  'user trump use hate putin win white hous trump press attack khan famili g p leader',
#  'one bucket list item tick tonight final saw ice cube live tonight wildlifefestiv today good day',
#  'friend magic potion ewabeach magicalhappydrink ewa beach hous',
#  'everytim wear soccer shi joie fri say look mexican fuck',
#  'weird month final feel posit life late pleasedontchang',
#  'check holiday croatia daystogo',
#  'user night sweet dream',
#  'nyc seven day newyork newyorkc travel bigappl',
#  'life make let make motiv',
#  'fashionblog rooster simul want climb vast expans mountain reach leakag coc',
#  'best mood ever becauseofhim inlov',
#  'happi worri smile love iminlov iam im nice day',
#  'user monaco resto chezedgard grandprixf essai sun lewissuppo user amour love',
#  'bought launch use design think user amp user via user toread letsmak',
#  'sukhbir badal announc offic bearer eastcoast zone canada',
#  'mad chose dj snake zedd edc',
#  'mango wood lett gbp get shop cool home fun',
#  'danger white liber oveurn appli liber men femin',
#  'user user user truli truli pathet mani way user user user noth learn coverin',
#  'monday morn work lake scottieandrussel work love picoftheday',
#  'love rain hope hang around rain water tbt weather bribieisland',
#  'user chosen wrong hors unless chang mind soon end polit career',
#  'user wed impoant celebr life possibl ann hathaway wed love',
#  'icymi shoot orlando nightclub kill polic say debelop gun',
#  'user user snatch past week schoolsuppli',
#  'great aicl right money starspangledbann slaveri apaheid usa',
#  'babi born welcom new world cat babiescat cat newborn congratul',
#  'pretend pain exampl strong person nighti',
#  'user user user user user even dear cuti',
#  'user user mental cultur mentalhealth',
#  'user wish us weekend',
#  'thank freezer thank posit',
#  'user readi lt gt full day lt html gt user user cssday',
#  'bihday cake made mom bihday mom fondant pumpkin chocol delici beauti amaz',
#  'user thank power social media user aand',
#  'user made smile bigbang babi cto',
#  'send good vibe way happi friday tgifriday goodvibesonli becauseimhappi smilemor',
#  'letsgo agent tooeasi day till dlc know gamingforeveryon',
#  'holi citi tissu',
#  'user old mom bihday',
#  'user decid fowoh goldenretriev lcck comfodog workingdog',
#  'user get angri muslim assassin much',
#  'hereeee user ericprydz edc music musiclif edm danc girl',
#  'funni thing humankind watch news feel bad etc back open busi usual good futur',
#  'user keep tell aryan allow rape women troll eod user user',
#  'user speechless come shoot recent guess peopl noth lose respect',
#  'user forecast beauti wave raalhugandu disappear due construct bridg amp there hope com',
#  'user minut trump condemn vile bigot comment surrog carlpaladino endhat',
#  'wish wonder dad father day let rock today red rascal',
#  'user allahsoil vp got multi million dollar bonus averag american lost home',
#  'love abrahamhick lawofattract healthi heal joytrain',
#  'model love u take u time ur',
#  'sign first bikram yoga class',
#  'think thought shine face like sun beam quot smile',
#  'want creativ worker give enough time play success quot',
#  'hea prayer orlando victim famili lgbt commun',
#  'jan interest discrimin affect crimin justic system',
#  'friend forev friend sweden reunion grate love egna hem',
#  'keep opposit user endthen',
#  'love pizza pizzaslic pizzaslic aoyama pizza yummi delicia goodtimeswithgo',
#  'two love beer craftbee dog malinoislov malinoi passion friend',
#  'abund posit affirm',
#  'fathersday father day dad skinni singl buy thing h',
#  'user rickiti rick rickiti rick ole broken wagon look find next mateen jump board',
#  'love citi great day cleveland home calm',
#  'guess user talk progress advanc misogyni homophobia bigotri',
#  'teen girl kill other injur downtown oakland shoot gun mentalil gang orlando',
#  'everyon go struggl pain right keep head keep smile get hope',
#  'good even darl instagram babi bless lipstick makeup fun grate share',
#  'user jake right mani ppl lack power take stand amp drown small mind amp oft evil tendenc past',
#  'realli hate hipocrit politician side deserv better citizen',
#  'user user user environment wellb plan site nothng todo w',
#  'bihday sway bihday sway bihday bihday',
#  'saturday morn go back sleep thetrust comus indi fade away johnmaun listen user',
#  'founat man life everi singl day father day',
#  'user user gut know tonight would good luck',
#  'begin think user tom bradi hater way goe man',
#  'attack orlando caus lot pain mani peopl vengeanc option let comfo',
#  'cute overload let life fill love sweet live long marri life',
#  'head graduat user mechtechplumb futureplumb proudmama',
#  'user user possibl speak topic without bring race bigot user',
#  'model love u take u time ur',
#  'much terribl news weekend orlando christinagrimmi prayer',
#  'make innov nou',
#  'updat social analyt instalik tbt yoga summer fun',
#  'rushlimbaugh incred obama impress via user',
#  'user user peopl fail fellow citizen',
#  'sta pack move newflat',
#  'first love may make feel like love chees shotermlongdist',
#  'user youtu bed two get friendship',
#  'want kind poor sin despis anyon jesu faith believ wisdom',
#  'nice life done tri lovequot',
#  'latest positivementalattitud thank user user user posit',
#  'want spark seriou debat gun violenc releas photo bodi insid club orlandoshoot gunviol',
#  'arriv blagoevgrad fo zaz conc feel umbrela',
#  'user number leader come',
#  'see user tcashowroom yesterday',
#  'user mean mean like',
#  'great way spend saturday relax positivevib california cakesbytheocean',
#  'eur usd could test near term westpac blog silver gold forex',
#  'money campaign ask k donat midnight fight hrc ad buy brokedonald lyindon',
#  'today call champagn friday fridayfeel friyay goodweek client hair',
#  'user user user rightli gop hate trump obama',
#  'user user user user user user user user sunday hug',
#  'us selfi myfriend loveh giannena smile thecomeback',
#  'moment decid need switch control life respons default',
#  'play yiruma kiss rain music song',
#  'simpl true becom capabl burnsurvivor dolbf motiv motiv',
#  'back miss greatfultogod beendoinggreat selfi',
#  'repeat put dog hot car leav heat keep home fuck sake dog',
#  'splendid nosi probabl year wrc rallypoland user user',
#  'hour go music video releas music edinburgh scotland band user musicvideo user',
#  'user confirm dead accord farrah gray pulseshoot',
#  'look journey left right foot stage',
#  'black professor make assumpt entir race whilst speak entir race next week jew',
#  'back music play michael jackson lost children unificationsday may god children amp famili smile',
#  'drakeandjosh buffalo simul buffalo take vicin home wa',
#  'trumpusa call us homophob misogynist realli say jealou us w',
#  'user think suspend indefininetli racist staff',
#  'sat alon let sad sigh openrp bore',
#  'good morn manchest quick preview new gin launch soon one',
#  'tri new user trailn v today although feel similar v v smoother feel great',
#  'kiki felt ignor today user make kiki danc kikid miabbook',
#  'user sourc inspir ideal lyf baba father day',
#  'user congrat thoma new beauti home tehaleh welcom lennar famili homeown',
#  'miss day friend play xbox',
#  'new case scraggli hair',
#  'user love dincwear mum da word user straight saturday brickingit',
#  'bihday sexi girl girl top boy nake',
#  'user one major fan like salti gsw fan need someon',
#  'user chang daili basi week handov user network team soon av',
#  'user come singapor',
#  'sma babi sock gbp get shop cool home fun',
#  'like user video user sjw retard want',
#  'user woh wait user doubledown wife user user veganbeerfest vegan',
#  'user lmfao deadass',
#  'amaz interview bjmckenzi born win bjmuzic',
#  'boasti tuesday last night boom boom harri hype say get',
#  'bihday balayya even age mass look craze fan screen romanc legend jaibalayya',
#  'woohoo kingsland highlandreserv hous famili build ourhom',
#  'outlin theme would poem haha',
#  'decor buffalo simul buffalo take vicin home way',
#  'sold one two paint go get beauti new home week sold',
#  'user msg hope newyear busi end endof tedtalk tedatibm user user',
#  'user slag children love show realli user',
#  'safe say miss marb sit home watch euro listen rain depress bringbackhappi',
#  'brainwash left allow terrorist come america kill',
#  'gd morn gdragon gd kwonjiyong jiyong vip bigbang handsom cute love',
#  'friendszxc',
#  'day till vacat',
#  'secret happi marriag find peopl less attract repo',
#  'python concurr best friend code restructur get concurr celeri develop python',
#  'womenareamaz think induoev superwomen follow dowhatyoulov',
#  'hairi pussi redtub hardcor track',
#  'let season bing begin oitnb myfavorit season weekendplan',
#  'rest peac christinagrimmi loss rip miss fan foreverinourhea',
#  'pictur woh thousand word sundayrewind hongkong travel ladi lawyer',
#  'relax inger followm follow follow follow beach pool relax enjoy coupl',
#  'user countdown begun famili freeevent festiv enteain food stall',
#  'awesom beginn gopro mount super use',
#  'dear istor pleas crash due heavi overload booktim muchlov',
#  'never underestim power good book good wine good food great patio summereven patioweath',
#  'istg best chees ta dayum expens',
#  'morn offic routin never without bff imi',
#  'model love u take u time ur',
#  'theshallow weak attempt cash jaw anniversari',
#  'user non stop elect blame cspan hide year pittsburgh california',
#  'extrem reveal first offici poster poalorigin pa come summer mo',
#  'minut count wwdc wwdc',
#  'user user play ball state polit facad lost princip',
#  'peopl protest trump republican trump fuher amp',
#  'great day noth happi bless thank',
#  'happi sunday everyon sundaymorn sunday peac love',
#  'alway help other never peopl matter clearli quot latenight',
#  'bihday weekend even better xx',
#  'stay strong selflov love ilovem quot quot quoteoftheday happi life wisdom wordsofwisdom',
#  'happi father day boy father sweet love memori user',
#  'aww yeah good bing bong bing bong',
#  'life impoant human spirit truth love give b spiritu thinkbigsundaywithmarsha',
#  'father babi love u happiest father day father via',
#  'user current mood user web develop meet amp hire',
#  'know get old sta get turn look poweool b amp q',
#  'project busi hand happi hand',
#  'user bride woman fine prospect happi behind ambros bierc wed love',
#  'friday xoxosamantha via',
#  'user stop rob innoc custom hard earn aiim guy idea dey manag recharg',
#  'grab besti amp swing hour miss fun eat',
#  'opinion racism degrad peopl base race justifi discrimin open violenc stoprac',
#  'final move today',
#  'user user user way say blogger vlogger',
#  'user user yay fantast edinburgh',
#  'lemm find put boiler month june',
#  'hea goe famili peopl kill massacr orlando',
#  'pre user gig drink passthecourvoisi user',
#  'rescu pup meet rexi rescuepup rexi pupsofsg suicidegirl beauti puppylov',
#  'video get excit futur tech augment futur mobil',
#  'user congrat ur wish come true work user superxcit song',
#  'wish',
#  'hellosunday hope beauti sunday sundayfunday sunnday',
#  'gif listen song sinc age',
#  'nzd usd rise eye gdt price index fomc statement blog silver gold forex',
#  'true home food consid cheap meal impress made restaur',
#  'happi bihday one west greatest tupac shakur bihday rip tupac',
#  'user live life',
#  'hr go fl motionpost reveal mupparimanam feel nervou stay tune',
#  'user littl tast sure',
#  'appletstag compleanno toa cake famili bday selfi smile girl summer',
#  'anim anim tree friend tag anim fana pixiv happi tree',
#  'user happi nd wed anniversari amaz husband user memori year lotstocom love',
#  'slow sta product day get back routin bout fatigu flareup hard spoonieproblem',
#  'love ramdan fast love iftar feel love way feel ramadan pray read quran bless',
#  'eur gbp subdu trade action around blog silver gold forex',
#  'user ngitingtagumpay',
#  'unusu cloudi day elect day picnic friend sunday everyon welcomeludovica',
#  'cloudchas gorilla simul need adapt environ need tear citi mat',
#  'christ aliv vlicob xoxo love grace amen share passion church life',
#  'want leak udta punjab probe suspect polit job jobsearch chandigarh maker udt',
#  'yesterday ozen restaur eatallyoucan',
#  'alreadi tell next week episod gonna give intens anxieti nervou gameofthron',
#  'got noth say assum ahahahahahah',
#  'ordinari girl intruduceyourself',
#  'user may light triumph dark may ramadan bring peac harmoni joy ramadan ramadankareem',
#  'user user els notic suppoer r pageant girl w year intern femal oppress system',
#  'user reason optimist rule world success growth balanc optim',
#  'hate onlin applic even get foot door tell need',
#  'thank flower thank posit',
#  'top crappi day w sign paper hous user pop conc block work amp know',
#  'beauti love live beach beach loveit',
#  'user omg bitch knew gone lil kim actual look like music video',
#  'tgif ff gamedev indiedev indiegamedev squad user user user user',
#  'user user user man even bunch coupon',
#  'way sta day goodmorn',
#  'lking forward water hole watchtow foress user user user',
#  'user allahsoil next best seller book isi islam world word terrorist gwot',
#  'fantast rub steak yum thespicesndteaexchang dc healthi',
#  'followm touch tit',
#  'feel like summer love like live life enjoy healthi sun tan bikini summer',
#  'teenageson reckon gone beyond call duti fathersday prezzi',
#  'user forget user research show sexist men psycholog problem tuckercarlson',
#  'nice specif pedagog chang',
#  'user typic citi fan',
#  'im attract asian ppl bc im asian tell im attract u bc im ins race hoe',
#  'user awlrit mol jealou better cricket pitch life getalif',
#  'prayer go eddi famili',
#  'nothappi carer finish one week',
#  'closeencount fatkind fatkid dese sick tire maybemono',
#  'gymmorgon gym morn strength energi train wingym',
#  'glad arriv safe user',
#  'defin histor oppress histor oppressor privileg',
#  'realli pretend truthseek empower selfimprov heal ihearadio',
#  'final found way delet old tweet might find use well deletetweet',
#  'user view oregon poland usa unitedst holiday dj produc hous',
#  'put vote yet havent share see make smile poll',
#  'user next chapter life sta soon look hous today fianc',
#  ...]

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\samar\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\samar\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
lm = WordNetLemmatizer()
cleaned_text_lm = []
def text_preprocessing_lm(l):
    text = re.sub("[^a-zA-Z]", ' ',str(l))
    text = text.lower()
    text = text.split()
    text = [lm.lemmatize(word) for word in text if not word in stopwords.words("english")]
    text = ' '.join(text)
    return text

# %%
cleaned_text_lm = []
for i in range(len(X)):
    cleaned_text_lm.append(text_preprocessing_lm(X[i]))

# %%
cleaned_text_lm
# Out:
# ['user father dysfunctional selfish drag kid dysfunction run',
#  'user user thanks lyft credit use cause offer wheelchair van pdx disapointed getthanked',
#  'bihday majesty',
#  'model love u take u time ur',
#  'factsguide society motivation',
#  'huge fan fare big talking leave chaos pay dispute get allshowandnogo',
#  'user camping tomorrow user user user user user user user danny',
#  'next school year year exam think school exam hate imagine actorslife revolutionschool girl',
#  'love land allin cavs champion cleveland clevelandcavaliers',
#  'user user welcome gr',
#  'ireland consumer price index mom climbed previous may blog silver gold forex',
#  'selfish orlando standwithorlando pulseshooting orlandoshooting biggerproblems selfish heabreaking value love',
#  'get see daddy today day gettingfed',
#  'user cnn call michigan middle school build wall chant tcot',
#  'comment australia opkillingbay seashepherd helpcovedolphins thecove helpcovedolphins',
#  'ouch junior angry got junior yugyoem omg',
#  'thankful paner thankful positive',
#  'retweet agree',
#  'friday smile around via ig user user cooky make people',
#  'know essential oil made chemical',
#  'euro people blaming ha conceded goal fat rooney gave away free kick knowing bale hit',
#  'sad little dude badday coneofshame cat pissed funny laugh',
#  'product day happy man wine tool weekend time open amp drink',
#  'user user lumpy say prove lumpy',
#  'user tgif ff gamedev indiedev indiegamedev squad user user user user user',
#  'beautiful sign vendor upsideofflorida shopalyssas love',
#  'user smile medium pressconference antalya turkey sunday throwback love',
#  'great panel mediatization public service ica',
#  'happy father day user',
#  'people went nightclub good night man action mean people lost family forever rip orlando',
#  'never chance vote presidential candidate excited cycle look different',
#  'alohafriday time exist positivevibes hawaiian user user user user',
#  'user rip fellow nohern ireland fan sadley passed away tonight gawa forever singing cheering fire',
#  'hard monday due cloudy weather disabling oxygen production today goodnight badmonday',
#  'unbelievable st century need something like neverump xenophobia',
#  'taylorswift bull dominate bull direct whatever want w',
#  'morning travelingram dalat ripinkylife',
#  'user one word tell photoshop enoughisenough dontphotoshopeverything wheresallthenaturalphotos',
#  'oh cedarpoint waited hour valravn line stopped working close',
#  'thankful sunshine thankful positive',
#  'finally finish book working awhile bookworm ontothenextnovel',
#  'yup knicks fan hard easier nba fan playoff roll around',
#  'life social networking embrace day',
#  'mom share bihday user bihday snake see weekend',
#  'lovely echeveria bloom flower grow gardening iphonesia bliss bloom basilicabotanica',
#  'amazing positive affirmation',
#  'model love u take u time ur',
#  'whenever im something go wrong',
#  'feeling blue illustration',
#  'best pa life knowing',
#  'abc getting ready remove victums frm pulseclub prayfororlando',
#  'bihday got nose job user bihday petunia love',
#  'concelebrate albanpilgrimage first time user',
#  'user let scum baggery begin',
#  'thank super love zpamdelacruz wedding dolores capas tarlac',
#  'scourge playing baroque piece piano beyond belief',
#  'user let fight love peace',
#  'happy father day mr rayos video father day rayos world hotvideo video',
#  'user ascot time babe ascot fashion monochrome style instahappyday',
#  'weekend selfie yolo xoxo like like',
#  'happy work conference right mindset lead culture development organization work mindset',
#  'christina grimmie last performance shot via user christinarip voice christinagrimmie',
#  'ready dance roar preschooler student proud',
#  'really hu feeling',
#  'user wife adore miss poland show surgery name bridget amp everything',
#  'user jealous right chatiado',
#  'celebrate every man played fatherly role father day',
#  'sure happy hour',
#  'white establishment blk folx running around loving promoting greatness',
#  'good morning journey begin travel yeah thejourneybegins hello',
#  'user luv hottweets like venusexchange',
#  'new brochure arrived exciting aworks solution',
#  'much stuff happening florida first orlando shooting disneygatorattack two year old kid',
#  'user ferrari sake championship gp clearly turning point rb ferrari mercs',
#  'aced first test proud',
#  'seek probe udtapunjab leak point finger amarinder aap',
#  'user wrapping senseaboutmaths user th user user user',
#  'user hey white people call people white user race identity med',
#  'user user might shown today regurgitated talking point name calling',
#  'sometimes raise brow raise bar golfstrengthandconditioning strong felixfoisgolf',
#  'greathonour careerconvos user user',
#  'user designing innovative learning space user include wateringhole cave mountaintop campfire user h',
#  'altright us amp insecurity lure men whitesupremacy',
#  'carrying gun helped take gun control stop black market terrorism get worse',
#  'use power mind heal body altwaystoheal healthy peace',
#  'woohoo week go',
#  'far away place family member hus',
#  'ready rehearse tonight new music new video look announcement midweek newmusic watchthisspace guitar',
#  'monday night pm channel finally get see fuss',
#  'watching new episode user user',
#  'user offline nice long night snapchat user redhead vermillionred',
#  'thing incredibly people',
#  'yes received acceptance letter master back user october goodtimes history',
#  'daughter riding bike around driveway son playing guitar u enjoy campfire summeime memory',
#  'omg loving station way jam work getting work done course memory user',
#  'user always hope one day get hug think gonna happen anytime soon',
#  'model love u take u time ur',
#  'couple sex fat naked japanese girl',
#  'hump hump day humpers edwardsville pennsylvania',
#  'personalised gbp get shop cool home fun',
#  'truly sick ppl',
#  'trump calling obama resign orlando shooting boy point year talk change',
#  'user user user user long nashvilletour nashvilleforever',
#  'eur usd clear barrier jump fresh week high blog silver gold forex',
#  'going la tomorrow',
#  'thankful good friend thankful positive',
#  'still wrap head around fact christinagrimmie gone fact man destroyed prayfororlando',
#  'received dis user wait sta baking eyelid',
#  'playing vigilfororlando harp clonakilty rip via user',
#  'user yes yes yes ihavenofriends someonecomewithme',
#  'sunday weekend relax icon woman sundaymorning sunday marilynmonroe',
#  'user interested linguistics address race amp racism power raciolinguistics brings',
#  'one beloved long lost cd recovered thanks apple music',
#  'marvel song musica weed ripchristina adele dance vine user',
#  'user user mocked obama black user user user user brexit',
#  'spell brexit referendum commerzbank blog silver gold forex',
#  'amazing health benefit cucumber healthy altwaystoheal',
#  'model love u take u time ur',
#  'work ofw pinoy followme igers instagood smile love',
#  'toradora anime animeedit made breakup alone lonely',
#  'lap pool k ride done picked gym membership form',
#  'cotd polar bear climb racing angry polar bear climb racing polar bear living cold place looking',
#  'user user get angry muslim assassinating much',
#  'happy snappy waiting football football snapchat',
#  'friday miss fringe qcbags summer',
#  'nochebuena lasvegas usa la vega strip',
#  'fleurette instaboy instaman sefie septum friend smile blackandwhite',
#  'sad branch rainy day writing tear flying bird haiku line micropoetry',
#  'yeah new button mail pretty jewelrymaking button',
#  'user driver hit female moose river rd weston moose killed driver ok crew removing animal',
#  'afterpas made japan madeinjapan eos cute fun cawaii love strawberry tomato',
#  'people protesting trump republican trump fuhered amp',
#  'need find way spend time always mind boy guy',
#  'update social analytics photooftheday igers like',
#  'anyone know date doj fbi became corrupted emailgate hillary shameful disgraceful ridiculous',
#  'stupidity make even negligence put sachintendulkar installation u going take',
#  'bihday thbihday bestfriend love',
#  'user impoant thing enjoy life matter life sho pooh u',
#  'happy bihday chris evans great actor human chrisevans bihday',
#  'heas thought prayer go people murdered gay nightclub florida',
#  'user demoing guitar new album newalbum indie guitar echobelly',
#  'retweeted lion pro user tgif webmareting seo community management weekend',
#  'nzd usd target week sma blog silver gold forex',
#  'user pretty bad bihday week far worst ever bihdayweeksucks bithday',
#  'blessed worked sa best leading lady',
#  'happiest place eah disneysmagickingdom disney magickingdom disneyland orlando',
#  'kinda among human',
#  'found user user exclaiming user gr blain hair nite',
#  'user lt listen beautiful best friend user singing amazing voice lt lt lt lt',
#  'n healthy freedom effo present merely mean effo stored past theodore roosevelt',
#  'know yall aint going know love commitment trust faithful',
#  'yes call michelleobama gorilla racist long thought black people bet',
#  'newarkfestival u year waiting show sta rd year running',
#  'internet broken watch netflix mochithepug puglife',
#  'user user user business usual',
#  'hbd dick suckin tequila lovin slut wouldnt want u way justalillate butstillontime',
#  'smaller hand show barry probably lied knicks game sucked golf',
#  'good morning friday everyone weekend goodmorning friday girl love florida',
#  'challenge aap claim punjabi drugaddicts dare prove',
#  'tracerequest sending deepest condolence orlando gay family zimbabwe gay community hea touched',
#  'new selfie guy mato chapones',
#  'saturday afternoon chi meet friend user user user',
#  'model love u take u time ur',
#  'soed nut amp bolt bloke',
#  'aww yeah good bing bong bing bong',
#  'dawned month seeing user live excited vfest summer',
#  'user happy th bihday shane robe watson bihday shane watson australia cricker',
#  'user user point one finger user million pointed right back jewishsupremacist',
#  'sad hear announcer say may moved player one two lead whoknows',
#  'radio going coldplay tonight oh yes',
#  'u think like god coming god keeping',
#  'user terrorist constitutional right another excuse republican appease nra gun control measure',
#  'user user gloucesterrugby',
#  'user sad user happened',
#  'everyone everything sad together alone fine dandy lonely exuberant depressed halffull halfempty',
#  'mikeashley sposdirectshame perhapse good example need protect workersrights within europe euref remain',
#  'angry bird stella bad princess bird stella bad princess birdsstellabadprincess time post wed',
#  'check user incredibly made great memory great people',
#  'saw shi last night said rip cared really',
#  'user hilarious user already blocked user asking one paicularly difficult question user',
#  'devastating news hea go victim family orlando heabreaking',
#  'happiness state arrive manner traveling margaret lee runbeck happiness quote inspirational',
#  'safe way heal acne altwaystoheal healthy healing',
#  'creating right beat makingbeats thursday work istandard akaipro',
#  'wedding number wedding weddingpay love forever weddingdress',
#  'looking forward attending cipd ireland conference amp workshop cpd onemoreday user user',
#  'finally reached follower twitch follower hypu stream tomorrow',
#  'word r free u use em cost verbal abuse hu love adult teen user',
#  'country went last year see people bring bomb stadium amp come everything football',
#  'thankful cat thankful positive',
#  'time eat bae swalscha dejeuner lunch happiness love amoureux',
#  'ilovethesecret lawofattraction quiz love happiness motivation success joy life',
#  'might libtard libtard sjw liberal politics',
#  'go pole bgp rozthediva blackgirlspole bodyandpole live love',
#  'argentina attack bull game really think head empty around city side',
#  'self serving hypocrite always keep eye bouncing ball nimrod president',
#  'nohcarolina bull dominate bull direct whatever want whe',
#  'building polar bear climb racing angry polar bear climb racing polar bear living cold place loo',
#  'user user want reelection money ksleg',
#  'hea orlando right truly cannot imagine could easily happened anywhere',
#  'alreemgroup aly alshahawy ad cute summer photographerdubai sun hair mydubai',
#  'seems like place action montreal',
#  'user old washed',
#  'spirited positive affirmation',
#  'thankful enteainment thankful positive',
#  'user user user show truly bad brisbane',
#  'user wait wimbledon',
#  'happy man success model entrepreneur speaker ff fresh confident fashion',
#  'gala moment day kid bipolar frikiegirl lucky chinatown mall binondo',
#  'really take piss angry go show valued complete utter moron',
#  'user take trash america voted hate voted voted vot',
#  'father day amazing dad give much family enjoy',
#  'magnettherapy really work altwaystoheal healing healthy',
#  'sebbo said user',
#  'eg smile smile egsmile torio',
#  'user brilliant service kettering branch today customer',
#  'user screening miss sing song potp shock treatment',
#  'way toraya bus alamindah white music carrieunderwood',
#  'model love u take u time ur',
#  'good day new beer bridpo food amp beer fest back campsite drunk user starstruck amp moved user',
#  'g l repost user propey ocean summer life family sydney',
#  'want teach love like never felt quote quote love pakistan allin girl boy fashion feeling',
#  'thankful thankful positive',
#  'omg day left countdown nolefam user wait come milan',
#  'user stone rose done time user club day',
#  'reason two people stay together give something nobody else hopelly great day',
#  'never know might crush wakow buzz moment ride love crush dating hookup app',
#  'friend got engaged',
#  'day lef b end classez yay risay risaypls',
#  'thursday may watch say need said',
#  'legendary positive affirmation',
#  'united state america rest world think proven right firearm',
#  'hold open door woman woman nice thing even try deny',
#  'good weekend show thankful blessed jeffreycwilliams',
#  'good hea help everyone always seem one get hu buttrue',
#  'happiest baby ive ever known cute smile babygirl beautiful niece blessed xo',
#  'ready b c oneteamlincoln user user user user',
#  'wait carowinds ready see user user time rockthepark timetogetmyjesuson',
#  'already bought finding dory ticket',
#  'every minute lose sixty second happiness',
#  'sanjapan animeconvention see guy september',
#  'question day excited moto tech announcement moto question',
#  'make today count mondaymotivation livelifetothefullest healthy everydaycounts',
#  'happy morning degree anna classmate friend',
#  'user would u able suppo event brentwood homesta lost funding may close',
#  'happy little people happyhappy people kitten cat blackkitten',
#  'user user user thank much oppounity cherish forever',
#  'themeowood puppy',
#  'day till',
#  'happy pharrell williams pharrellwilliams lyric',
#  'user happy w ork conference right mindset lead culture development organization work',
#  'lost another member family yesterday gutted rosie',
#  'yayyy trailer morrow fever super user user user',
#  'watch fancy tail vine mad mad teeth bite pissed dog biting dogbite dogtreat',
#  'dreamcatcher bull dominate bull direct whatever want',
#  'ready tomorrow englishteacher teacher ecuador',
#  'memory wonderful dad always missed eternally loved strong greatquotes',
#  'user user dallas shooting video see disturbing viewer discretion play loop ove',
#  'itako alone fine little',
#  'sunshine amp sticker kind saturday letthembelittle childhoodunplugged',
#  'wonderful day today calm sunny chubbygirl glass finnishgirl finn',
#  'buka bersama tma family yuhuuuuu tma w risha meylucky amp others mayfair townhouse pic',
#  'love know nationalbestfriendsday true',
#  'user man ran governor ny state biggest african american population',
#  'stereotyping prejudice offer hope solution create old repetitive hate conflict',
#  'get pussy quicker day',
#  'probably time user come back home ugh',
#  'model love u take u time ur',
#  'user anyone playing voez kinda love game game gaming girlgamer voez',
#  'many pol passed many time said nothing bluelivesmatter draintheswamp ferguson',
#  'sequoia weekend',
#  'bitch care eyebrow much makin end week',
#  'bham pride paradeready beyou ofbham user user user',
#  'fathersday guy play dad love',
#  'bihday bogummy love forever hope happy everyday good night user',
#  'wishing client baby goat cuddle',
#  'positivevibes fresh love guy get concord mill mall',
#  'conjuring get ready scared tonight readyornot truestory',
#  'today day make change eliminate negativity choose live positive lifestyle instead',
#  'user aaahh nabilah look arigatou jkt happy daaay iwearbanana',
#  'last day work tomorrow self employed monday scared redditchbizhour',
#  'user im half boy half man im dumb',
#  'happy little boy smile corbinrayp',
#  'never appropriate zero idea feeling right scared missyou whatwasthat',
#  'user magnificent monday mondaymorning mondaymotivation monday indraloka',
#  'dont understand designer print animal fabric bought user muzlin b sanasafinaz noexchangepolicy',
#  'maybe happy hour get ending',
#  'littlebear friend joy toddlerfriends puresweetness latergram toddlerfun',
#  'never lost loved one senseless violence get fucking opinion nd amendment',
#  'world heading could lose life leaving home orlando',
#  'heard say trying lock shooter kept patron getting',
#  'good mood flight user munich user interview pharrell',
#  'first presentation user netherlands user',
#  'u made u proud hv reading ur word amp assured b assoment petite emotion wish u best',
#  'happiness v joy happiness temporary leaf u hu joy last forever never leaf real tru',
#  'twinklatinboys na slut snapshot hot nasty naughty sexy horny shy porn nude kinky xxx',
#  'user people thankful thankful people happy thankfulthursday',
#  'creative positive affirmation',
#  'held back tear cried happy tear amp finally leave week tomorrow user user canadianravers',
#  'bihday pressie mummy granny michaelkors luckygirl bihday liverpool',
#  'user stuck athens instead santorini user said windy land shocking service every level since',
#  'user happy folk first freakshake launch freak yum dalston user',
#  'huge crowd trump',
#  'thankful saturday thankful positive',
#  'good god',
#  'user enjoying delicious melon vegan organic fresh fruit organic healthy healthyliving life',
#  'first month week day till beginning end user sad time',
#  'firework weeheeeee',
#  'blackpool attack bull game really think head empty around city side',
#  'fathersday amazing father today',
#  'want much ask',
#  'user ready waiting newblood',
#  'sad aunt passed away funeral',
#  'horribly ad made u cringe',
#  'mind robson kanu decent player available free transfer',
#  'user come user better please put user shoe unnecessary stress h',
#  'stalk watch peon poor disabled kill usa usa used b proud amp universe care',
#  'stephcurry outburst begs question christian get nbafinals',
#  'grateful affirmation',
#  'week go im san antonio bound see user cant wait see little brother missyou mybrotherskeeper',
#  'listen gt gt gt gt gt gt gt',
#  'user dying light village green town antisemitism hocoschools columbiamd hocomd',
#  'hahaha last friday amp weird',
#  'hey noticed u training lover ask u check free app known training apple',
#  'sexy fuck directioner niall nialhoranfacts niallerwins hot justindrewbieber justindb believetou',
#  'user father sday say love dad right sanya whererefreshingbegins',
#  'guess back back lifeaftersurgery dog dogslife labrador labradorretriever lifeofsam',
#  'hey superspoilt may want check latest update glastofest',
#  'user user user user user bihday sid god bless hav successful career',
#  'nba final ambivalent love steph thompson kyrie stinking green class doosh lebron talk guillermo',
#  'check production team web series episode edited truly mep webseries',
#  'model love u take u time ur',
#  'user never answered statement nazi hatred amp bigotry found w',
#  'juneteenth independenceday food thought rich ancestral heritage independence hall',
#  'river gorilla simulator need adapt environment need tear city material',
#  'watching user leadership embrace amp kiss donald as pathetic amp user pay pay racism amp hate ripgop',
#  'love mature age',
#  'aww yeah good bing bong bing bong',
#  'user good feeling happens smile instalike instamood instapic',
#  'check graffiti dublin ireland music vimeo movie video europe people flow fun rafalwojcicki',
#  'oitnbseason day aaahhhhh',
#  'user user iampossible today extraordinaryladyspeaks starawards user user ht',
#  'sun happy thursday breakfast sun day sunnyday sun blue',
#  'packing sneak peek working yellowjackets neshl user bhl hockey',
#  'tony sunday tonyawards',
#  'happy father day dad dad father day',
#  'user theverdict idiot country rock bluegrass beatles love pop romance',
#  'project week june blog silver gold forex',
#  'user dayshappy user dayseventyseven day happiness love lifequotes life',
#  'little brother higher tolerance alcohol lol',
#  'wishing guy bihday blaze say user spitting image',
#  'thankful hiking trail thankful positive',
#  'pay meeting tackle movie uncovers problem want world know',
#  'user chill relaxing piano music keep pet quiet july th firework',
#  'might libtard libtard sjw liberal politics',
#  'user nothing say merica like user tweet',
#  'always paratyphoid',
#  'user today lost thevoice sister senselessly sing love death people stopthehate ripchristina',
#  'guy concerned twitter brand honest follower',
#  'hate like family really born big as toxic bomb mother fucker give fuck cuz got money',
#  'get get get enjoy music today free apps free music',
#  'best lawofattraction resource healing altwaystoheal healthy idwp',
#  'trump ny co chair make racist remark michelle obama p p fyi tcot',
#  'user fan make',
#  'music therapy tool healing altwaystoheal healthy',
#  'food make family fight mxm',
#  'delicious sangria salud cheer smile pub pembroke',
#  'fabulous weekend beautiful soul nofilter',
#  'feeling overwhelmed look see million reason happy love craig',
#  'back day job shane lowry',
#  'hour right bottle amp drink pm user w chippewa st buffalo',
#  'ana nimra farishta mawia khushal number mark obtained damn high p',
#  'monday empty without bachelorette thebachelorette empty nowine',
#  'suppoing family god chivalry tradition pride one heritage controversial',
#  'user pic say otherwise young girl confined kitchen void meaning beyond cheap publicity topoli',
#  'good night faith ever vaitacacommafiasdv',
#  'love simply love love success work business',
#  'lunchtime mom torrington lunch afterschool instadaily yummy withmom user',
#  'user sister even know watching argue nigga waiting say wrong shit',
#  'ride ride back done cycling sunset ride bike fitness cardio dese',
#  'well gonna go see adtr bae',
#  'user tagsforlikes food friend summer swag quote love god girl weekend polaroid followme teen win job',
#  'payintheusa polar bear climb racing angry polar bear climb racing polar bear living cold place',
#  'healthy fam',
#  'dream palace move already stellar girl dreamy goodmorning day',
#  'im waiting follow since x factor',
#  'user fault use pointscore',
#  'user week staed kinda lame getting better yay wednesdaywisdom',
#  'user forever user young man luks hot wen temper b alwys ur fan till lst breath h',
#  'worry bee',
#  'double tap follow beautiful smooth lifestyle skin instasize f f fashion',
#  'lawofattraction healing loa healthy well idwp',
#  'oil turn flat eyeing eia inventory data fuher direction blog silver gold forex',
#  'training new employee fun newblood',
#  'first bihday puppy eloise sweetbabins dog growingup cute bihdaygirl user',
#  'user pig burn alive saskatchewan barn fire video',
#  'user never convince american right bear prayfororlando guncontrol',
#  'beautiful lady blessing know smile lovethem',
#  'today baba siddique ifftar pay mumbai user amp user dono ayenge see',
#  'hand ombre blue',
#  'user wait go see warcraft ugh warcraft',
#  'cousin reunited family fun user wellness',
#  'user audience duane henry insightful',
#  'train moved binge tweeting',
#  'lover stop angry visit u gt gt gt lover friend astrologer love',
#  'user blocked troll promise blacklivesmatter amp let nonsensical rant boo',
#  'father day dad one heaven',
#  'sdl user june user',
#  'creepy awesome baboon climbing fire escape like human user summev zoo',
#  'use power mind heal body altwaystoheal healthy',
#  'dude tiger roar tiger annaswelshzoo bihdaycelebrations',
#  'user laugh happy laugh william james xtra',
#  'happy sunday everyone think today going good day positivevibes sunshine sunday',
#  'talk way organization dehumanize u never held accountable',
#  'stuck rat race find freedom masterkeyexperience',
#  'study face pizza stole roommate idea taking pic',
#  'dinner sister sisteradventures sister ilovemysister',
#  'else planning watching user tomorrow',
#  'usn rifle day snowed ar closest ever got user user user navy',
#  'euro bbc pundit make prediction france euro sta today',
#  'user happy happiness minion',
#  'elder scroll many year wah wah bethesda e e',
#  'user poor tiggy little bit cheeky jax amp soa throwbackthursday user user user',
#  'cannot wait eurogamer year pumped eurogamer',
#  'work russell beckwith soon staytuned friend lyle tapfoags',
#  'nazi studied american race law inspiration ushistory eugenics',
#  'sharing ice cream sun love outdoors picnic summer family daughter father desse icecream',
#  'nothing like river island sale shopping spree cheer retailtherapy riverisland shoppingqueen alwayscheersyouup',
#  'cleaning ze house zoing ziy laundry finally free fever cold happy cleaning laundryday',
#  'new listing ebay woohoo sell selling buy shop shopping',
#  'thankful challenge thankful positive',
#  'chilled night ice cream amp grown chilled',
#  'user biherism absolutely originated hateful bigotry altright hatred african american potus theresistance',
#  'user sweet instagood idola idol followme selfie',
#  'tragedy america first killing christinagrimmie orlando america safe place today',
#  'brexit angst factor helping drive interest rate germany japan bbh blog silver gold',
#  'fab amp interesting day eacbpm dash quiet place dial iiba emea region meeting busy',
#  'kayak sup snorkel swim whatever pleasure put together alohabeachbus hawaii explore',
#  'u hold man year watch change u hear say loyalty',
#  'back going tacloban see ya later great traveling tacloban city catbalogan',
#  'user feel olympics medal',
#  'angry bird il film download ita p hdtc bird download film il ita',
#  'sunday photo user model urbex topless tit mono retweet sexy heel ace',
#  'fo woh officer viral arrest video rude racist chief crime officer',
#  'user user user user saturday friend',
#  'yayyyy friend got married today congratulation guy shegotmarried',
#  'model love u take u time ur',
#  'lewis remains perfect ranger announcer gonna stroke',
#  'chris back soccer missing spring season broken',
#  'train ticket booked opera week wale',
#  'beautiful day sun fun beachpark beach park',
#  'big screen fitted right euro',
#  'love story happy ending anime love story ending like like',
#  'poet bull dominate bull direct whatever want sta',
#  'tranquil positive affirmation',
#  'user name upcoming new track pm kpop',
#  'best essentialoils anxiety healthy peace altwaystoheal',
#  'user user user wow people child nothing better insult people twitter',
#  'thinking maybe bought user instead user gettingold becomingboring notborderlands goblizzard',
#  'fact user album hour away dripping losing mind fatkidinacandystore',
#  'ryderrideu see c c cum together snapshot young shy kinky wet porn hot xxx horny',
#  'snapchat gaby china love girl snapchat flower instasmile instalove',
#  'brilliant positive affirmation',
#  'user true nigga dont go looking apaments go look shoe jewelry',
#  'safe way heal acne altwaystoheal healthy healing',
#  'msgapparelstoday user u r special u father day',
#  'camping next weekend lovecamping brownwood',
#  'grateful affirmation',
#  'forever bestie karaoke friend friendship love nofilter instacool instagood',
#  'user absolutely love place fantastic welcome carlos receptionist th time room request granted usual',
#  'headed thealter peculiar family',
#  'u retail sale control group likely rose may danske bank blog silver gold forex',
#  'happy father day love life amp best father world user fathersday love',
#  'coolestlifehack world smallest snake motivation',
#  'shockingly increasingly violent world live uk gun control law feel mp family amp friend',
#  'funny simply truestory',
#  'happy bihday brithday day holiday monday menmodels',
#  'saddened one thought groom position asking opinion issue',
#  'ukrainian athlete grosseto user watching livestream without seeing',
#  'new season oitnb stas tonight oitnbseason',
#  'user excited side cuain tonight looking forward seeing user broadway',
#  'quay collab user say sold noooo whyyyy loveyoudesi',
#  'finally get jordan get paid wear lowtops',
#  'impressive positive affirmation',
#  'father day father making happen salute',
#  'view th floor nyc newyorkcity myview girl wine fridaynight',
#  'discussing republican thing critiquing ignore consequence',
#  'got school tomorrow last integration',
#  'amen truth always lt lt love blessed',
#  'user stamford kid got month rape boredom minute action',
#  'let colorized life w rainbow danian love colour rainbow depok',
#  'aiel aielmaharashtra rude customer care executive make want switch loyalty another provider irritated',
#  'hi teddy corpuz rocksteddy band enjoy idol omg',
#  'user wow great daughter send father right father day cheapshot lowblow shame',
#  'reason happy kid mid tantrum parenting tantrum toddler calm mindfulness strong',
#  'truthful positive affirmation',
#  'yup siri macos wwdc woot next work listening skill',
#  'diy done dresser nicknack newelectricscrewdriver brockely london',
#  'black amp feel like stomping retweet tampa miami',
#  'user user thats problem one police officer need bigger gun perhaps one tank soldier',
#  'father day friend',
#  'choice fall always write candidate',
#  'user ending',
#  'get know team behind app keeping tummy june issue user bazaarmag',
#  'actually going fishing today somewhere nice',
#  'cute look like doll',
#  'user im',
#  'love vacation enjoy greece crete sabinedrift chillinn blondegirl bluedress',
#  'user unreal advisor refuse take payment say wait pcn customer service ur site wasnt working',
#  'user gameready forza horizon pc time live',
#  'user life better tahiti summer life school tahiti like',
#  'know male thought vagina like video game xd stupidthoughts quote lmao',
#  'pa pack taken brainwashed cheetah downasquadmember treeouts',
#  'japan domestic corporate good price index yoy line expectation may blog silver',
#  'remember day people bbuk went become reality tv star seems reality tv star become big brother contestant',
#  'user allahsoil familiar become difficult stereotype',
#  'user good morning want live life tie goal people thing',
#  'user friday lt fridayfeeling relax user bristol',
#  'day porn movie pussy pay pic',
#  'looked easy till turn rap hiphop rock funny comedy pop kanyewest',
#  'banner merry christmas new year freepik ad decoration newyear',
#  'user user yay thanks letting know pa happy man',
#  'exam room testing tired annoyed',
#  'best homeopathic remedy anxiety altwaystoheal healing peace',
#  'rest peace christina',
#  'bamas fool around might raising child ppl dont think far advance see fun whatever',
#  'anti racist codeword antiwhite asia asian africa african white country everyon',
#  'user periscope first god baby graduated high school collegebound',
#  'nearly folk nervous curious finalised stuff pointer grainne bringiton',
#  'fellowship lifegroup',
#  'caught eating chocolate sliced bread beside ref realizing still eat dinner',
#  'user praised cleveland police rnc police consent decree white tamirrice rip',
#  'best lawofattraction resource healing altwaystoheal healthy idwp',
#  'everything need surfday fathersday dad novyspos novytowel surfgear',
#  'user agree',
#  'user next show monday fiddler elbow camden looking like going huge night ht',
#  'user swimming sign everywhere parent watching year old',
#  'mitchellrattle mitchell goodson',
#  'user getting ready saturday jeep run nbjc day showyourjeepday jeepmafia jeeplife jeep htt',
#  'user attempt czech fury croatia score second',
#  'latest dairy k thanks user user user',
#  'user yep grateful everyday gratitude laurasworld',
#  'ebook awhile nice hard copy',
#  'nba final game could basketball fan ask nbafinals',
#  'user prevent bigot',
#  'dear uot despite attempt savecharity regret announce lost tragic rip angelic friend miss u',
#  'space place color blue fabricsourcing finished pillow cushion use u',
#  'perfect moment day',
#  'waited user hour come autograph finally walk away come course disappointing',
#  'fathersday gift dad secured financial future save insure invest',
#  'girl world sexy mature housewife',
#  'time get happy saturday saturday weekend',
#  'awesome dad almighty father lord darling dad rip sweethea husband baby daddy st son fathersday',
#  'owen football tornament football',
#  'come ee piss poor reception today month struggle get signal buxton put mast switching grumpy',
#  'excited na',
#  'user let troopingthecolour begin bihdayyourmajesty thequeenat ht',
#  'work fusiona wolf last stage development chase user user',
#  'user like blacklivesmatter slogan talk',
#  'r p little bear bear hamster rip imissyou',
#  'give hug love cat moment',
#  'lip like fire blood like gasoline love boyfriend smile',
#  'go let people icrs',
#  'life race allow present user fun',
#  'dental testimonial lichfield client',
#  'thank soo much pretty user feel soo blessed amp lucky plz keep showering ur lyks surprised like unexpected',
#  'user user user nice c susanna smiling day need false promise flying dragon got ben',
#  'user back yet',
#  'got call yesterday mom diagnosed stage ovarian cancer terrified terrified know',
#  'user feminismiscancer feminismisterrorism feminismmuktbharat malevote ignored user',
#  'user user user side history ally issue embarrassing',
#  'fox new coming saying bluntly one thing read',
#  'good morning internationaldayofyoga yogalove yoga relax healthy positive',
#  'user monkey also declared vermin protest bajrang dal user user',
#  'user new plant user ready garden gardening know',
#  'user coldplay last night fave coldplay conce hampden fave couple cute',
#  'use power mind heal body altwaystoheal healthy peace',
#  'flagday mine gorgeous texas sky householdname takingover',
#  'aww yeah good bing bong bing bong',
#  'user yes let suppoing openly prowar anti islamic homophobic rapist advocate hypocrite',
#  'cat furry persiancat pixion wallpaper image',
#  'good moooooorning tgif kiss kiss friday fridayfun',
#  'user enjoy everything already given rather always needing blessed thankful',
#  'euro match schedule design france v romania feedback appreciated',
#  'father day take dad user love',
#  'berlin thank much user incredible theriveourberlin theboss',
#  'listen incubus never hus nowplaying sick little world nissan live set de user',
#  'user anderson cooper amp lemon like gay thrown building sharia ndamendment',
#  'bei field dog walking dog',
#  'would steal awork user boohiss',
#  'competing listing today whenrealtorscompeteyouwin callme gotheextramile',
#  'user great park totally disorganised one poaventura whatajoke',
#  'got news bernie winning dc even vote held last month dcvotes',
#  'eur usd printing new monthly top draghi eyed blog silver gold forex',
#  'two presidential candidate everybody devolved election america smh usa',
#  'poor pup animal puppy vine magic subscribe youtube vine user',
#  'rare pic superstar user user bihday sivakoratala',
#  'user user moving outside downtown gr mi neither offer better mbps',
#  'user wishing dad happy father day dad fathersday intellicred',
#  'met girl yr ago online b ng gay friend look like b user',
#  'face say pwcproud',
#  'b u love instagood user tbt cute beautiful followme',
#  'enjoy weekend family home happy weekend dear friend weekend family home',
#  'another senseless tragedy tragic pulse orlandostaystrong thoughtsandprayers',
#  'user loving yrkkh frm bottom hea frm day stared amp v get return uglyspat user user',
#  'captain felix rutland water little boat behind go grand adventure',
#  'binge watching series thekilling completely avoid football',
#  'quote jeremy corbyn fucking go',
#  'happy travel time instamood moment love mylife russian girl model like',
#  'porn vids wwwsmallgirlsexcom',
#  'user tuesday jackie quote taketime make soul enjoylife smile believe dream havefun',
#  'home sweet home call edinburgh since moving year ago scotland homesweethome family',
#  'play england v russia marseille expect high risk game plenty time drink',
#  'aww yeah good bing bong bing bong',
#  'thankful sweater weather thankful positive',
#  'haunting atmospherics studiotime',
#  'user user become fan give right criticize personal life idol',
#  'latest obsidian radio daily thanks user user user latesnews',
#  'mind blown learning much google form workshop user cfisdrrr',
#  'user sexy prettypussy sexybbw realmvp',
#  'user back user v traumatic month damage bad thought proof plan work onwards amp upwards excit',
#  'might libtard libtard sjw liberal politics',
#  'overwhelming evidence company trump keep echo sentiment amp ideal dumptrump',
#  'user female beefed community dick as nigga',
#  'people like already forgot nah new name made hashtag weekly basis',
#  'answer',
#  'cherry color symbol warm positive energy necklace price aed stone gift amazing beautiful',
#  'wait season begin lfc ynwa englishpremierleague',
#  'user happy father day dad except rogergoodell fathersday goodellsucks',
#  'orb independent brexit poll show leave vote ahead gbp usd slump blog silver gold forex',
#  'user user user mm mm washout flooding good take set another day golf',
#  'user ya ever since zayne left never',
#  'happy father day loveyou fathersday sunday father daddy day',
#  'big shock monday needed find new home yeah found dream cottage tuesday',
#  'save thousand free search x logins x broker actor seeklearning stafresh',
#  'actually ordered kylie lip kit',
#  'hope family made arrangement make sure bastard user get access',
#  'socialmedia u firm build nuclear reactor india',
#  'smaphone bull dominate bull direct whatever want',
#  'lifeisbeautiful loveit workhard trainhard matter go blessed fitlife',
#  'oscar tabarez talk luis suarez angry reaction spos luis oscar',
#  'playing njoyhit hitmusicstation u uk eur user join u nice nyc user',
#  'user week go personaltrainer full time new slot available june pls spread',
#  'mother take care ten child sometime ten child cant take care mother',
#  'thankful good night sleep thankful positive',
#  'playing bride nocturne melancholy melancholymusic',
#  'tvk fathersday father day tatay daddy enjoy wathing tha voice kid',
#  'thankful friend thankful positive',
#  'thankful mason jar thankful positive',
#  'nigger lifelessons white kid grew blogpost whitepeople respect',
#  'user user user congrats user',
#  'via jts user love sinkthepink music instagay celebspot',
#  'user ready user ccmf mychurch frontrow upshow',
#  'utterly people incurable stupidity africa albino killing malawi spark education campaign',
#  'gold high back around blog silver gold forex',
#  'shocking event orlando usa review gun law innocent die first horrific unforgiveable',
#  'knowledgeable positive affirmation',
#  'le sister instatraveling instamoment igdaily instagramhub instagood instalike',
#  'feeling lonely',
#  'girliguessimwithher tag saddest representation people feel forced vote',
#  'h factor mobile app make user want factor click download aricent whitepaper',
#  'user meanwhile google violates free speech',
#  'happy work conference right mindset lead culture development organization work mindset',
#  'user rochester attack bull chase leave lot despite fact strong source f',
#  'user competition',
#  'tattoosleeves gorilla simulator need adapt environment need tear city',
#  'ima go cry hour brb',
#  'tell sorrow river river taught flow without complain sepatu dahlan philosophy proverb',
#  'thankful memory thankful positive',
#  'user surely nasty piece work lmao',
#  'today perfect day happiness lifecoach reinventimpossible',
#  'sex sex nake woman',
#  'thankful cocktail thankful positive',
#  'dont wait outside thepeel work homophobic taxi driver guy kiss gay melbourne cab',
#  'user guess one wanted let resident spring street know able leave hour today',
#  'great morning deborah user smile kindness day',
#  'window split screen browser customcasetab noedit',
#  'user people use tragedy like fuel hate agenda towards entire group people opposite helpful',
#  'taeyeon unnie fire btw really hope album cover yellow lol',
#  'john mica hell people like elected user user totalpolitician outoftouch disgraceful',
#  'nothing make dad happier tasty meal fathersday',
#  'truth suicide rate young blackboys',
#  'happy sunday homesweethome amazing love istanbul girl beautiful instalike',
#  'oh blocked least love island look forward sunday',
#  'playing suzanne ciani clock morning music song',
#  'swing swing mybabygirl baby littlegirl park love cute',
#  'help bubble attack winter bathtime cozy',
#  'moving positive affirmation',
#  'thing matter many law regulation gun people still find way get hand',
#  'user sunflower nature garden photograpy quality print amp card',
#  'user didnt stay long emergency home daughter well soo rush home missed ur set',
#  'user great insight trusted profession emea growth hacking conference growthwithhubspot',
#  'carolyn cooper ugly poor ignorant black',
#  'franklin dog sunshine dogsoftwitter',
#  'perfect day buy real furniture hiking user dinner user desse sleepnumber bonustolongrest dnd',
#  'happy face lovely smile user satisfying hair workit smile face',
#  'love sunday weekend selfie longhair girl selfporait love',
#  'nature perfection bull hill climb reach target complete task survive str',
#  'model love u take u time ur',
#  'orlando gay men angry amp donate blood massacre',
#  'user golinglobal golinuntern fresh air trail running soul keeping golinuntern life balance',
#  'user user monroe amp nick best friend amp rosalee amp addie kelly amp babymonrosale grimm family nadalind',
#  'user lying hillary would call security inquiry liberal like minded one eats shit eat shit',
#  'know find incredibly disrespectful taking personal call meeting frustrated',
#  'date night friday pub ilovehim instagay beer billy burnet',
#  'wish user would make phone damn screen shatter cost arm leg still gotta pay fix em',
#  'hea wrenching would state mother know son die',
#  'user time fly le week go brilliant user lead summer conference',
#  'fruit time fruit desse instamoment photooftheday yvr sweet vancitybuzz',
#  'sad one gt gt gt',
#  'sirf ashiq log follow karen iqbal galib wasi faraz mohsin ki full poetry add follow user',
#  'user minute go armaanamaalontkss user user user',
#  'thank god royal without kansa city right cleveland disgraced',
#  'get see favorite person tmrrw',
#  'latina buffalo simulation buffalo take vicinity home way',
#  'world live orlando',
#  'user vacation begun triathlete triathlon coach vacation fearless rul htt',
#  'user bit heabreak reflective',
#  'user peaceful way sta morning daily chaos begin gratitude',
#  'hardcore girl video birday sex xxx',
#  'takalot book order arrives time long weekend away bush bengreenfield',
#  'saysomething bull dominate bull direct whatever want',
#  'steph san kana badly needed please',
#  'user another hand amp foot complete berachah best amp tired',
#  'user way ctf book talk inmate paicipating user book club program slugg',
#  'ready awesome beat cool dj dance edm house goodmusic madness',
#  'jpy negative external environment remains suppoive mufg blog silver gold forex',
#  'mkf collection jasmine moira crossbody bag wednesday',
#  'currently eat steakandshake minute gotten shake ordered',
#  'gray sad color make feel grayneedstogo',
#  'difficult road often lead beautiful destination anon leadership inspiration quote inspirational',
#  'usd long position added eur shos increased anz blog silver gold forex',
#  'r rockalldayer user user day noise',
#  'user definitely mexican fakenewsale',
#  'user new album released user break loveherbreakups hotgoss',
#  'standing racism hate americad curse congress hater deplorable hate',
#  'sunshine sunshine make sky gray',
#  'something wanted say something make happy gaming gamer xboxone playstation user e',
#  'football actually thing mo watchable bringbackgladiators',
#  'happy hump day humpday life lifestyle wednesday midweek snapchat walrus funny',
#  'let say love',
#  'worry happy via user archiveday weekendblogshare happiness quote tshis',
#  'great thing never came comfo zone goodtogreat inspireme love',
#  'happy puppy london puppy thursdaymotivation',
#  'know going room one troubled soul drawing blackandwhite',
#  'recommend dark amp romance horror moviegenres ambiance',
#  'user trump used hate putin win white house trump press attack khan family g p leader',
#  'one bucket list item ticked tonight finally saw ice cube live tonight wildlifefestival today good day',
#  'friend magical potion ewabeach magicalhappydrinks ewa beach house',
#  'everytime wear soccer shis joie fry say look mexican fuck',
#  'weird month finally feeling positive life lately pleasedontchange',
#  'checked holiday croatia daystogo',
#  'user night sweet dream',
#  'nyc seven day newyork newyorkcity travel bigapple',
#  'life make let make motivation',
#  'fashionblog rooster simulation want climb vast expanse mountain reached leakage coc',
#  'best mood ever becauseofhim inlove',
#  'happy worry smile love iminlove iam im nice day',
#  'user monaco resto chezedgard grandprixf essais sun lewissuppo user amour love',
#  'bought launch using design thinking user amp user via user toread letsmake',
#  'sukhbir badal announces office bearer eastcoast zone canada',
#  'mad chose dj snake zedd edc',
#  'mango wood lett gbp get shop cool home fun',
#  'danger white liberalism oveurning applies liberal men feminism',
#  'user user user truly truly pathetic many way user user user nothing learned coverin',
#  'monday morning working lake scottieandrussell work love picoftheday',
#  'loving rain hope hang around rain water tbt weather bribieisland',
#  'user chosen wrong horse unless change mind soon end political career',
#  'user wedding impoant celebrate life possibility anne hathaway wedding love',
#  'icymi shooting orlando nightclub kill police say debeloping gun',
#  'user user snatched past week schoolsupplies',
#  'great aicle right money starspangledbanner slavery apaheid usa',
#  'baby born welcome new world cat babiescat cat newborn congratulation',
#  'pretending pain example strong person nighty',
#  'user user user user user evening dear cutys',
#  'user user mentality culture mentalhealth',
#  'user wishing u weekend',
#  'thankful freezer thankful positive',
#  'user ready lt gt full day lt html gt user user cssday',
#  'bihday cake made mom bihday mom fondant pumpkin chocolate delicious beautiful amazing',
#  'user thank power social medium user aande',
#  'user made smile bigbang baby cto',
#  'sending good vibe way happy friday tgifriday goodvibesonly becauseimhappy smilemore',
#  'letsgo agent tooeasy day till dlc know gamingforeveryone',
#  'holy city tissue',
#  'user old mom bihday',
#  'user decide fowoh goldenretriever lcck comfodog workingdog',
#  'user get angry muslim assassinating much',
#  'hereeeee user ericprydz edc music musiclife edm dance girl',
#  'funny thing humankind watch news feel bad etc back open business usual good future',
#  'user keep telling aryan allowed rape woman troll eod user user',
#  'user speechless come shooting recently guess people nothing lose respect',
#  'user forecasted beautiful wave raalhugandu disappeared due construction bridge amp there hope com',
#  'user minute trump condemn vile bigoted comment surrogate carlpaladino endhate',
#  'wishing wonderful dad father day let rock today red rascal',
#  'user allahsoil vps got multi million dollar bonus average american lost home',
#  'love abrahamhicks lawofattraction healthy healing joytrain',
#  'model love u take u time ur',
#  'signed first bikram yoga class',
#  'think thought shine face like sun beam quote smile',
#  'want creative worker give enough time play success quote',
#  'hea prayer orlando victim family lgbt community',
#  'jan interested discrimination affected criminal justice system',
#  'friend forever friend sweden reunion grateful love egna hem',
#  'keep opposition user endthenation',
#  'love pizza pizzaslice pizzaslice aoyama pizza yummy delicias goodtimeswithgo',
#  'two love beer craftbeee dog malinoislovers malinois passion friend',
#  'abundant positive affirmation',
#  'fathersday father day dad skinny single buy thing h',
#  'user rickity rick rickity rick ole broken wagon looking find next mateen jump board',
#  'love city great day cleveland home calm',
#  'guess user talking progress advancement misogyny homophobia bigotry',
#  'teen girl killed others injured downtown oakland shooting gun mentalillness gang orlando',
#  'everyone going struggle pain right keep head keep smiling get hope',
#  'good evening darling instagram baby blessed lipstick makeup fun grateful share',
#  'user jake right many ppl lack power take stand amp drown small minded amp oft evil tendency past',
#  'really hate hipocrit politician side deserve better citizen',
#  'user user user environmental wellbeing plan site nothng todo w',
#  'bihday sway bihday sway bihday bihday',
#  'saturday morning go back sleep thetrust comusic indie faded away johnmaun listen user',
#  'founate man life every single day father day',
#  'user user gutted know tonight would good luck',
#  'beginning think user tom brady hater way go man',
#  'attack orlando caused lot pain many people vengeance option let comfo',
#  'cuteness overloaded let life fill love sweetness live long married life',
#  'heading graduation user mechtechplumbing futureplumber proudmama',
#  'user user possible speak topic without bringing race bigot user',
#  'model love u take u time ur',
#  'much terribly news weekend orlando christinagrimmie prayer',
#  'make innovative nous',
#  'update social analytics instalike tbt yoga summer fun',
#  'rushlimbaugh incredibly obama impression via user',
#  'user user people failing fellow citizen',
#  'staing pack move newflat',
#  'first love may make feel like love cheese shotermlongdistance',
#  'user youtu bed two get friendship',
#  'want kind poor sin despise anyone jesus faith believe wisdom',
#  'nice life done trying lovequotes',
#  'latest positivementalattitude thanks user user user positive',
#  'want spark serious debate gun violence release photo body inside club orlandoshooting gunviolence',
#  'arrived blagoevgrad fo zaz conce feeling umbrelas',
#  'user number leader coming',
#  'see user tcashowroom yesterday',
#  'user mean mean like',
#  'great way spend saturday relaxation positivevibes california cakesbytheocean',
#  'eur usd could test near term westpac blog silver gold forex',
#  'money campaign asking k donation midnight fight hrc ad buy brokedonald lyindon',
#  'today call champagne friday fridayfeeling friyay goodweek client hair',
#  'user user user rightly gop hate trump obama',
#  'user user user user user user user user sunday hug',
#  'u selfie myfriend loveher giannena smile thecomeback',
#  'moment decided needed switch control life response default',
#  'playing yiruma kiss rain music song',
#  'simple true becoming capable burnsurvivor dolbf motivation motivate',
#  'back missed greatfultogod beendoinggreat selfie',
#  'repeat put dog hot car leave heat keep home fuck sake dog',
#  'splendid nosie probably year wrc rallypoland user user',
#  'hour go music video released music edinburgh scotland band user musicvideo user',
#  'user confirmed dead according farrah gray pulseshooting',
#  'look journey left right foot stage',
#  'black professor make assumption entire race whilst speaking entire race next week jew',
#  'back music playing michael jackson lost child unificationsday may god child amp family smile',
#  'drakeandjosh buffalo simulation buffalo take vicinity home wa',
#  'trumpusa call u homophobic misogynist really saying jealous u w',
#  'user think suspend indefininetly racist staff',
#  'sat alone let sad sigh openrp bored',
#  'good morning manchester quick preview new gin launching soon one',
#  'tried new user trailn v today although feel similar v v smoother feel great',
#  'kiki felt ignored today user make kiki dance kikidance miabbook',
#  'user source inspiration ideal lyf baba father day',
#  'user congrats thomas new beautiful home tehaleh welcome lennar family homeowner',
#  'miss day friend played xbox',
#  'new case scraggly hair',
#  'user loving dincwear mum da word user straight saturday brickingit',
#  'bihday sexy girl girl top boy naked',
#  'user one majority fan like salty gsw fan needed someone',
#  'user changing daily basis week handover user network team soon av',
#  'user coming singapore',
#  'sma baby sock gbp get shop cool home fun',
#  'liked user video user sjw retard want',
#  'user woh wait user doubledown wife user user veganbeerfest vegan',
#  'user lmfao deadass',
#  'amazing interview bjmckenzie born win bjmuzic',
#  'boasty tuesday last night boom boom harry hype say get',
#  'bihday balayya even age mass look craze fan screen romance legend jaibalayya',
#  'woohoo kingslanding highlandreserve house family building ourhome',
#  'outlining theme would poem haha',
#  'decor buffalo simulation buffalo take vicinity home way',
#  'sold one two painting going get beautiful new home week sold',
#  'user msg hope newyear business end endof tedtalks tedatibm user user',
#  'user slag child love show really user',
#  'safe say missing marbs sitting home watching euro listening rain depressing bringbackhappiness',
#  'brainwashed left allowing terrorist come america kill',
#  'gd morning gdragon gd kwonjiyong jiyong vip bigbang handsome cute love',
#  'friendszxc',
#  'day till vacation',
#  'secret happy marriage finding people le attractive repo',
#  'python concurrency best friend code restructure get concurrency celery developer python',
#  'womenareamazing think induoevents superwomen follow dowhatyoulove',
#  'hairy pussy redtube hardcore track',
#  'let season binge begin oitnb myfavorite season weekendplans',
#  'rest peace christinagrimmie loss rip missed fan foreverinourheas',
#  'picture woh thousand word sundayrewind hongkong travel lady lawyer',
#  'relax inger followme follow follow follow beach pool relax enjoy couple',
#  'user countdown begun family freeevent festival enteainment food stall',
#  'awesome beginner gopro mount super use',
#  'dear istore please crash due heavy overload booktime muchlove',
#  'never underestimate power good book good wine good food great patio summerevening patioweather',
#  'istg best cheese ta dayum expensive',
#  'morning office routine never without bff imy',
#  'model love u take u time ur',
#  'theshallows weak attempt cash jaw anniversary',
#  'user non stop election blame cspan hiding year pittsburgh california',
#  'extremely reveal first official poster poalorigins pa coming summer mo',
#  'minute counting wwdc wwdc',
#  'user user play ball state politics facade lost principality',
#  'people protesting trump republican trump fuhered amp',
#  'great day nothing happy blessed thankful',
#  'happy sunday everyone sundaymorning sunday peace love',
#  'always help others never people matter clearly quote latenights',
#  'bihday weekend even better xx',
#  'stay strong selflove love iloveme quote quote quoteoftheday happiness life wisdom wordsofwisdom',
#  'happy father day boy father sweet love memory user',
#  'aww yeah good bing bong bing bong',
#  'life impoant human spirit truth love give b spirituality thinkbigsundaywithmarsha',
#  'father baby love u happiest father day father via',
#  'user current mood user web developer meet amp hire',
#  'know getting old sta get turned looking poweools b amp q',
#  'project busy hand happy hand',
#  'user bride woman fine prospect happiness behind ambrose bierce wedding love',
#  'friday xoxosamantha via',
#  'user stop robbing innocent customer hard earned aiime guy idea dey managed recharge',
#  'grab bestie amp swing hour missed fun eat',
#  'opinion racism degrading people based race justify discrimination open violence stopracism',
#  'finally moving today',
#  'user user user way say blogger vlogger',
#  'user user yay fantastic edinburgh',
#  'lemme find put boiler month june',
#  'hea go family people killed massacre orlando',
#  'pre user gig drink passthecourvoisier user',
#  'rescued pup meet rexy rescuepup rexy pupsofsg suicidegirls beautiful puppylove',
#  'video get excited future tech augmented future mobile',
#  'user congrats ur wish come true working user superxcited song',
#  'wish',
#  'hellosunday hope beautiful sunday sundayfunday sunnday',
#  'gif listen song since age',
#  'nzd usd rise eyeing gdt price index fomc statement blog silver gold forex',
#  'true home food considered cheap meal impression made restaurant',
#  'happy bihday one west greatest tupac shakur bihday rip tupac',
#  'user live life',
#  'hr go fl motionposter revealed mupparimanam feeling nervous stay tuned',
#  'user little taste sure',
#  'appletstag compleanno toa cake family bday selfie smile girl summer',
#  'anime anime tree friend tag anime fana pixiv happy tree',
#  'user happy nd wedding anniversary amazing husband user memory year lotstocome love',
#  'slow sta productive day getting back routine bout fatigue flareup hard spoonieproblems',
#  'love ramdan fasting love iftar feeling love way feel ramadan praying reading quran blessed',
#  'eur gbp subdued trading action around blog silver gold forex',
#  'user ngitingtagumpay',
#  'unusual cloudy day election day picnic friend sunday everyone welcomeludovica',
#  'cloudchaser gorilla simulator need adapt environment need tear city mat',
#  'christ alive vlicobs xoxo love grace amen share passion church life',
#  'want leak udta punjab probed suspect political job jobsearch chandigarh maker udt',
#  'yesterday ozen restaurant eatallyoucan',
#  'already tell next week episode gonna give intense anxiety nervous gameofthrones',
#  'got nothing say assume ahahahahahah',
#  'ordinary girl intruduceyourself',
#  'user may light triumph darkness may ramadan bring peace harmony joy ramadan ramadankareem',
#  'user user else notice suppoers r pageant girl w year internalize female oppressive system',
#  'user reason optimist rule world success growth balance optimism',
#  'hate online application even get foot door tell need',
#  'thankful flower thankful positive',
#  'top crappy day w signing paper house user pop conce block work amp know',
#  'beautiful love living beach beach loveit',
#  'user omg bitch knew gone lil kim actually look like music video',
#  'tgif ff gamedev indiedev indiegamedev squad user user user user',
#  'user user user man even bunch coupon',
#  'way sta day goodmorning',
#  'lking forward watering hole watchtower fore user user user',
#  'user allahsoil next best seller book isi islam world word terrorist gwot',
#  'fantastic rub steak yum thespicesndteaexchange dc healthy',
#  'followme touch tit',
#  'feel like summer love like live life enjoy healthy sun tan bikini summer',
#  'teenageson reckons gone beyond call duty fathersday prezzie',
#  'user forget user research show sexist men psychological problem tuckercarlson',
#  'nice specific pedagogical change',
#  'user typical city fan',
#  'im attracted asian ppl bc im asian tell im attracted u bc im inse race hoe',
#  'user awlrite mol jealous better cricket pitch life getalife',
#  'prayer go eddie family',
#  'nothappy carer finishing one week',
#  'closeencounters fatkind fatkid dese sick tired maybemono',
#  'gymmorgon gym morning strength energy training wingym',
#  'glad arrived safely user',
#  'defines historically oppressed historic oppressor privileged',
#  'really pretending truthseekers empowerment selfimprovement healing ihearadio',
#  'finally found way delete old tweet might find useful well deletetweets',
#  'user view oregon poland usa unitedstates holiday dj producer house',
#  'put vote yet havent share see make smile poll',
#  'user next chapter life stas soon looking house today fianc',
#  ...]

# %%
def text_embedding(vocab_size,cleaned_text):
    ohe = [one_hot(i,vocab_size) for i in cleaned_text]
    count_array = []
    count = 0
    for i in range(len(cleaned_text)):
        count = len(cleaned_text[i].split())
        count_array.append(count)
    sentence_length_padding = max(count_array)
    embeddings = pad_sequences(ohe,padding="pre",maxlen=sentence_length_padding)
    return embeddings,sentence_length_padding

# %%
vocab_size = 50000
embeddings_ps,sentence_length_padding = text_embedding(vocab_size,cleaned_text_ps)
embeddings_lm,sentence_length_padding = text_embedding(vocab_size,cleaned_text_lm)

# %%
dimensions = 100
model_ps = Sequential()
model_ps.add(Embedding(vocab_size,dimensions,input_length=sentence_length_padding))
model_ps.add(SpatialDropout1D(0.2))
model_ps.add(LSTM(100,dropout=0.2,recurrent_dropout=0.2))
model_ps.add(Dense(1,activation="sigmoid"))
model_ps.compile(loss="binary_crossentropy",optimizer="adam",metrics=["accuracy"])
model_ps.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_9 (Embedding)     (None, 37, 100)           5000000
#
#  spatial_dropout1d_2 (Spati  (None, 37, 100)           0
#  alDropout1D)
#
#  lstm_6 (LSTM)               (None, 100)               80400
#
#  dense_3 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 5080501 (19.38 MB)
# Trainable params: 5080501 (19.38 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
dimensions = 100
model_lm = Sequential()
model_lm.add(Embedding(vocab_size,dimensions,input_length=sentence_length_padding))
model_lm.add(LSTM(100,dropout=0.1,recurrent_dropout=0.1))
model_lm.add(Dense(1,activation="sigmoid"))
model_lm.compile(loss="binary_crossentropy",optimizer="adam",metrics=["accuracy"])
model_lm.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_12 (Embedding)    (None, 37, 100)           5000000
#
#  lstm_9 (LSTM)               (None, 100)               80400
#
#  dense_6 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 5080501 (19.38 MB)
# Trainable params: 5080501 (19.38 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
X_final_ps = np.array(embeddings_ps)
X_final_lm = np.array(embeddings_lm)
y_final = np.array(y)

# %%
from sklearn.model_selection import train_test_split
X_train_ps,X_test_ps,y_train_ps,y_test_ps = train_test_split(X_final_ps,y_final,test_size=0.2,random_state=42)
X_train_lm,X_test_lm,y_train_lm,y_test_lm = train_test_split(X_final_lm,y_final,test_size=0.2,random_state=42)

# %%
model_ps.fit(X_train_ps,y_train_ps,epochs=5,batch_size=64)
# Out:
# Epoch 1/5
# 400/400 [==============================] - 35s 83ms/step - loss: 0.1763 - accuracy: 0.9453
# Epoch 2/5
# 400/400 [==============================] - 31s 79ms/step - loss: 0.0798 - accuracy: 0.9723
# Epoch 3/5
# 400/400 [==============================] - 32s 80ms/step - loss: 0.0467 - accuracy: 0.9844
# Epoch 4/5
# 400/400 [==============================] - 33s 81ms/step - loss: 0.0276 - accuracy: 0.9904
# Epoch 5/5
# 400/400 [==============================] - 32s 81ms/step - loss: 0.0174 - accuracy: 0.9943

# %%
model_lm.fit(X_train_lm,y_train_lm,epochs=5,batch_size=64)
# Out:
# Epoch 1/5
# 400/400 [==============================] - 32s 76ms/step - loss: 0.1746 - accuracy: 0.9448
# Epoch 2/5
# 400/400 [==============================] - 30s 76ms/step - loss: 0.0679 - accuracy: 0.9763
# Epoch 3/5
# 400/400 [==============================] - 31s 78ms/step - loss: 0.0337 - accuracy: 0.9888
# Epoch 4/5
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0161 - accuracy: 0.9950
# Epoch 5/5
# 400/400 [==============================] - 32s 80ms/step - loss: 0.0087 - accuracy: 0.9974

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
def accuracy(model,X_test,y_test):    
    y_pred = model.predict(X_test)
    y_pred = np.where(y_pred>0.5,1,0)
    accuracyScore = accuracy_score(y_test,y_pred)
    confusionMatrix = confusion_matrix(y_test,y_pred)
    return accuracyScore,confusionMatrix

# %%
as_ps,cm_ps = accuracy(model_ps,X_test_ps,y_test_ps)
as_lm,cm_lm = accuracy(model_lm,X_test_lm,y_test_lm)
# Out:
# 200/200 [==============================] - 1s 6ms/step
# 200/200 [==============================] - 1s 6ms/step

# %%
as_ps,cm_ps
# Out:
# (0.9568277803847959,
#  array([[5826,  111],
#         [ 165,  291]], dtype=int64))

# %%
as_lm,cm_lm
# Out:
# (0.9552635695291726,
#  array([[5805,  132],
#         [ 154,  302]], dtype=int64))

# %% [markdown]
# ## Shallow Machine Learning Models

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn import naive_bayes
from sklearn.ensemble import GradientBoostingClassifier

# %%
LR_model = LogisticRegression()
SVC_model = LinearSVC()
NB_model = naive_bayes.MultinomialNB()
RFC_model = RandomForestClassifier()
GBC_model = GradientBoostingClassifier()

# %%
LR_model.fit(X_train, y_train)
SVC_model.fit(X_train, y_train)
NB_model.fit(X_train, y_train)
RFC_model.fit(X_train, y_train)
GBC_model.fit(X_train, y_train)
# Out:
# C:\Users\khushi garg\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\khushi garg\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# GradientBoostingClassifier()

# %%
shallow_models = [LR_model, SVC_model, NB_model, RFC_model, GBC_model]

# %%
def accuracy(shallow_models, X_test, y_test): 
    accuracyScore = []
    confusionMatrix = []
    for i in shallow_models:
        y_pred = i.predict(X_test)
        y_pred = np.where(y_pred>0.5,1,0)
        accuracyScore_val = accuracy_score(y_test,y_pred)
        confusionMatrix_val = confusion_matrix(y_test,y_pred)
        
        accuracyScore.append(accuracyScore_val)
        confusionMatrix.append(confusionMatrix_val)
    return accuracyScore,confusionMatrix

# %%
model_names = ["Logistic Regression", "Support Vector Classifier", "Naive Bayes", "Random Forest Classifier", "Gradient Boosting Classifier"]

# %%
def print_model_metrics(models, model_names, X_test, y_test):
    accuracy_scores, confusion_matrices = accuracy(models, X_test, y_test)
    for model_name, accuracy_score_value, confusion_matrix_value in zip(model_names, accuracy_scores, confusion_matrices):
        print(f"Model: {model_name}")
        print(f"Accuracy Score: {accuracy_score_value:.4f}")
        print("Confusion Matrix:")
        print(confusion_matrix_value)
        print("\n")

# %%
print_model_metrics(shallow_models, model_names, X_test, y_test)
# Out:
# Model: Logistic Regression
# Accuracy Score: 0.9287
# Confusion Matrix:
# [[5937    0]
#  [ 456    0]]
#
#
# Model: Support Vector Classifier
# Accuracy Score: 0.9260
# Confusion Matrix:
# [[5919   18]
#  [ 455    1]]
#
#
# Model: Naive Bayes
# Accuracy Score: 0.5584
# Confusion Matrix:
# [[3312 2625]
#  [ 198  258]]
#
#
# Model: Random Forest Classifier
# Accuracy Score: 0.9395
# Confusion Matrix:
# [[5932    5]
#  [ 382   74]]
#
#
# Model: Gradient Boosting Classifier
# Accuracy Score: 0.9343
# Confusion Matrix:
# [[5937    0]
#  [ 420   36]]
